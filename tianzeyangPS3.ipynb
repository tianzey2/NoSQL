# %%
from pymongo import MongoClient
import pymongo
from bson.objectid import ObjectId

db_url="mongodb://mongodb:mongodb@cluster0-shard-00-00.wxx0a.mongodb.net:27017,cluster0-shard-00-01.wxx0a.mongodb.net:27017,cluster0-shard-00-02.wxx0a.mongodb.net:27017/test?ssl=true&replicaSet=atlas-p5zfhi-shard-0&authSource=admin&retryWrites=true&w=majority"
client = MongoClient(db_url)

# See all databases: list(client.list_databases())
airbnb=client['sample_airbnb']['listingsAndReviews']
geospatial=client['sample_geospatial']['shipwrecks']
netflix=client['sample_mflix']
movies=client['sample_mflix']['movies']
supplies=client['sample_supplies']['sales']
training=client['sample_training']
companies=client['sample_training']['companies']
weather=client['sample_weatherdata']['data']
grades = training['grades'] 


# OTHER NOTES --- 
# list dbs
# list_databases()

# list collections
# list_collection_names()

# SORT --> SKIP --> LIMIT
# collection.distinct('address.country')
# Query construction
# collection.find() 
# collection.count_documents()

# %% [markdown]
# ### All Query Operators discussed below can be found here:
# https://docs.mongodb.com/manual/reference/operator/query/

# %% [markdown]
# ## Problem 1
#
# Find a document in the movies collection where all the following are true:
#
# ~~~
# 1) "genres" is not in the following: "Drama","Fantasy". Use the NOT operator.
# 2) "countries" is in "USA","Spain" OR "languages" is "English"
# 3) "imdb.rating" is greater than 7 OR "tomatoes.viewer.rating" is greater than 4
# 4) Limit to 1 result
# 5) Sort by year descending and title descending
# 6) Return the following fields: "_id,"genres", "countries", "languages","imdb", "tommatoes", "title"
# ~~~

# %% [markdown]
# **expected output**
#
#
#
# ```
# [{'_id': ObjectId(),
#   'countries': ['country1','country2'...],
#   'genres': ['genre1','genre2'...],
#   'imdb': {'id': ..., 'rating': ..., 'votes': ...},
#   'languages': ['lang1','lang2'...],
#   'title': 'some title'}]
# ```

# %%
list(movies.find({"genres": { '$not': { '$in':["Drama","Fantasy"] } },
            "$or":[{"countries":["USA","Spain"]},
                   {"languages":"English"}],
            "$or":[{"imdb.rating":{'$gt':7}},
                   {"tomatoes.viewer.rating":{'$gt':4}}]
           
           }
           ,{'_id':1,"genres":1,"countries":1,"languages":1,"imdb":1,"tommatoes":1,"title":1})
     .sort([('year',-1),('title',-1)])
     .limit(1))
# Out:
# [{'_id': ObjectId('573a13eaf29313caabdcfbc1'),
#   'genres': ['Documentary'],
#   'countries': ['USA'],
#   'title': 'The Roosevelts: An Intimate History',
#   'languages': ['English'],
#   'imdb': {'rating': 8.8, 'votes': 682, 'id': 3400010}}]

# %% [markdown]
# ## Problem 2 - double negative & "is_past" must exist
#
# Find a document in the companies collection where:
#
# ~~~
# 1) "founded_year" is in the following: 2006, 2008, 20012
# 2) Where not any "is_past" field in the array of embedded objects "relationships" field is equal to False. Also the "relationships.is_past" field must exist.
# 3) Return only the relevant fields in the query criteria - "relationships", "founded_year" and "_id".
# 4) Limit to 1 result
# 5) Sort on "founded_year" in ascending order
# ~~~

# %% [markdown]
# **expected output**
#
#
#
# ```
# [{'_id': ObjectId(''),
#   'founded_year': 1999,
#   'relationships': [{'is_past': True,
#     'person': {'first_name': 'Tony',
#      'last_name': 'Stark',
#      'permalink': 'tony-stark'},
#     'title': 'title1'},
#    {'is_past': True,
#     'person': {'first_name': 'first2',
#      'last_name': 'last2',
#      'permalink': 'first-last'},
#     'title': 'title'}]}]
# ```

# %%
list(companies.find({"founded_year":{"$in":[2006,2008,2012]},
            "$and":[{"relationships.is_past":{"$exists":True}},
                   {"relationships.is_past":{"$not":{"$eq":False}}}] 
           }
           ,{'_id':1,"relationships":1,"founded_year":1})
     .sort("founded_year",1)
     .limit(1))
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297dae'),
#   'founded_year': 2006,
#   'relationships': [{'is_past': True,
#     'title': 'Founder and CEO',
#     'person': {'first_name': 'Ian',
#      'last_name': 'Clarke',
#      'permalink': 'ian-clarke'}},
#    {'is_past': True,
#     'title': 'Board',
#     'person': {'first_name': 'Ian',
#      'last_name': 'Clarke',
#      'permalink': 'ian-clarke'}}]}]

# %% [markdown]
# ## Problem 3
#
# Find documents in the airbnb where:
# ~~~
# 1) the “number_of_reviews” is greater than 100
# 2) "beds" is greater than 5 OR "review_scores.review_scores_rating" is greater than 97
# 3) "host.host_is_superhost" is set to True OR "property_type" is a Villa
# 4) Limit to 1 result
# 5) Sort on "beds" in descending order
# ~~~

# %% [markdown]
# **expected output**
#
#
# ```
# [{'_id': 'id1',
#   'beds': #,
#   'host': {'host_is_superhost': True},
#   'name': 'name1',
#   'number_of_reviews': #,
#   'property_type': 'value',
#   'review_scores': {'review_scores_rating': #}}]
# ```

# %%
list(airbnb.find({'number_of_reviews':{"$gt":100},
            "$or":[{"bed":{"$gt":5}},
                   {"review_scores.review_scores_rating":{"$gt":97}}],
            "$or":[{"host.host_is_superhost":True},
                   {"property_type":'Villa'}]}
      
         )
     .sort('beds',-1)
     .limit(1))
# Out:
# [{'_id': '1095174',
#   'listing_url': 'https://www.airbnb.com/rooms/1095174',
#   'name': 'Makai Hideaway',
#   'summary': "This house is a hidden treasure. It is located one hour south of Kona and 65 miles  from Volcano National Park. It has fantastic ocean views and a wonderful deck.House is on an old lava flow -shop before you come as nearest  store is  22  minutes away!  12  minutes off highway 11 descend a curvy road with phenomenal ocean views.I think it's one of the best views on the island! Our house is 600 feet from the ocean! Walk to snorkeling/swimming hole in 3 minutes! There isn't a beach right by house.",
#   'space': "A Hideaway quiet and peaceful, set in an authentic fishing village. Unwind and relax from city life and packaged vacations. Three bedroom, three baths, and game room. A large Lanai runs the length of the house for dolphin and whale watching. Have dinner on a beautiful Lanai and watch the incredible sunsets enjoy the warm climate with cool coastal breezes. One and half blocks to water access for swimming, snorkeling, kayaking, scuba diving and fishing. There are kayaks and boogie boards ... at the house. The Milolii area is famous for deep sea fishing, and you can watch the fishing boats or go out yourself.Whales frequent Papa bay from December  through mid- March.The beautiful secluded Honomolino Beach is close by-short walk along the coast from Milolii State Park-watch the spinner dolphins, snorkel with the fish in the coral, and maybe see a sea turtle or a rare Hawaiian monk seal. There are wild goats over on Umi street and the king's hiking trails is a 3 minute walk away. Many peopl",
#   'description': "This house is a hidden treasure. It is located one hour south of Kona and 65 miles  from Volcano National Park. It has fantastic ocean views and a wonderful deck.House is on an old lava flow -shop before you come as nearest  store is  22  minutes away!  12  minutes off highway 11 descend a curvy road with phenomenal ocean views.I think it's one of the best views on the island! Our house is 600 feet from the ocean! Walk to snorkeling/swimming hole in 3 minutes! There isn't a beach right by house. A Hideaway quiet and peaceful, set in an authentic fishing village. Unwind and relax from city life and packaged vacations. Three bedroom, three baths, and game room. A large Lanai runs the length of the house for dolphin and whale watching. Have dinner on a beautiful Lanai and watch the incredible sunsets enjoy the warm climate with cool coastal breezes. One and half blocks to water access for swimming, snorkeling, kayaking, scuba diving and fishing. There are kayaks and boogie boards ... at t",
#   'neighborhood_overview': "I love walking the streets to get exercise. Cars are traveling slowly in the neighbourhood. Speed limit is 15 miles per hour. The swimming hole is two minutes away- go northwest on Kai street to find- its over by the bay. That's where we put kayaks in. There are tide pools in the village and the wharf is a great snorkeling place as is the swimming hole by the house. There really isnt a beach close to the house but drive  into the village of Milolii  , the last hawaiian fishing village,park, and hike  15 minutes into Honomolino Beach, a pretty, quiet, black sand beach with a patch of white on the southern part.",
#   'notes': 'Seeing the dolphins in Papa bay and the humpback whales in the winter are a great experience.    Also, there are wild goats over on Umi Street. There are tide pools before you reach the community center on the right side. Buy fish in the village or up at the top of the hill- sushi grade Ahi tuna is wonderful!  Ono is also a great fish to cook in butter and enjoy.',
#   'transit': "You  need to have a rental car for this house. Four  wheel drive is a great addition to your car experience on the island- there are lots of places on  the island to enjoy 4 wheel drive- you don't need it though to reach the house- roads are paved but curvy to the house.",
#   'access': 'There are boogie boards, snorkel gear and beach toys in the closet  on the first floor. There are a gazillion DVDS and netflix  in the house. The kayaks are great! There is a play station in the lower master and WII is in a box in the closet- feel free to use.',
#   'interaction': "Most of the year  I am in California  so my interaction with guests is via email  but I am happy to answer any and all questions. There is an orange folder  titled Welcome Book on the desk or bar  with ideas of what to do plus there are guidebooks in the house. Please leave them for future guests when you leave. Daniel's latest favorite thing is manta ray diving on the Hang Loose Boat which is north of Kona.  Talk to him about it if you are interested! Everything is a drive on the Big Island so be prepared for that!",
#   'house_rules': "Aloha.First of all have a wonderful trip and thank you for renting our home! We continue to share as most people have been very considerate of our house! Please be very careful of water usage.  Larger groups  and sometimes longer groups due to utilities and cleaning fees have larger fees cleaning plus utitlities so inquire first before you book.  If you arrive with extra guests they are 50 dollars per day per person  plus extra cleaning. Please advise me two weeks before your arrival of any people changes . Only two year old kids and under are free- there is a charge for all extra people over the age of 2.   Smoking is allowed outside of the house but not inside please. Please use ashtrays.Please put furniture back where it started.Please don't bring metal furniture into house as it scraps the  bamboo floors.Again  Rules are on fridge. Internet password is all over the house. There will be a  cancellation charge to a reservation that holds up my house for 6 months or more and then canc",
#   'property_type': 'House',
#   'room_type': 'Entire home/apt',
#   'bed_type': 'Real Bed',
#   'minimum_nights': '4',
#   'maximum_nights': '180',
#   'cancellation_policy': 'strict_14_with_grace_period',
#   'last_scraped': datetime.datetime(2019, 3, 6, 5, 0),
#   'calendar_last_scraped': datetime.datetime(2019, 3, 6, 5, 0),
#   'first_review': datetime.datetime(2013, 10, 21, 4, 0),
#   'last_review': datetime.datetime(2019, 3, 2, 5, 0),
#   'accommodates': 14,
#   'bedrooms': 4,
#   'beds': 8,
#   'number_of_reviews': 119,
#   'bathrooms': Decimal128('3.0'),
#   'amenities': ['TV',
#    'Cable TV',
#    'Internet',
#    'Wifi',
#    'Kitchen',
#    'Free parking on premises',
#    'Smoking allowed',
#    'Family/kid friendly',
#    'Suitable for events',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    '24-hour check-in',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Private living room',
#    'Bathtub',
#    'Children’s books and toys',
#    'Pack ’n Play/travel crib',
#    'Game console',
#    'Hot water',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'BBQ grill',
#    'Patio or balcony',
#    'Garden or backyard',
#    'Host greets you'],
#   'price': Decimal128('169.00'),
#   'weekly_price': Decimal128('732.00'),
#   'monthly_price': Decimal128('2600.00'),
#   'security_deposit': Decimal128('200.00'),
#   'cleaning_fee': Decimal128('200.00'),
#   'extra_people': Decimal128('25.00'),
#   'guests_included': Decimal128('4'),
#   'images': {'thumbnail_url': '',
#    'medium_url': '',
#    'picture_url': 'https://a0.muscache.com/im/pictures/b424aa3e-f161-4b7e-a4dc-ff0cb70bc9e8.jpg?aki_policy=large',
#    'xl_picture_url': ''},
#   'host': {'host_id': '6017048',
#    'host_url': 'https://www.airbnb.com/users/show/6017048',
#    'host_name': 'Cheryl',
#    'host_location': 'Escondido, California, United States',
#    'host_about': "I am a first grade teacher who enjoys teaching young children. I grew up in the  the Mid-West and saw the beauty of living in California.  I was born in Venezuela and have always worked on both English and Spanish, and am able to teach both languages.  My dream was to have a home in Hawaii.  I've have spent the last few years traveling  between CA  and many of the Hawaiian Islands in search of the perfect home.  We are settling on the shores of this quaint village.  I am married with one 15 year old son, and one dog Max. I love to hike and the kings trail is close to this house. I love nature and there are wild goats over on Umi street. I love to watch movies and there is netflix at the house. I love geckos and there are brown and green ones at the house. I like deals and the Aloha Beach house is one! There is a king bed now in the master- everytime we go we make the house nicer! It's nicer than our house in California. The master bedroom downstairs is very large and has a queen bed and futon. House can accomodate large groups; I just have to charge extra due to utilities. We get lots of family groups!\r\n\r\nThis beach house has been a 30 year dream in the making!  It is always so incredible when you see your dreams come true with belief and hard work. Please come and share the  Fantastic Sunsets at  Makai Hideaway- The sunsets are phenomenal and the snorkeling / swimming hole is a two minute walk from the house. The beach is a 15 minute hike from the community center in Milolii. I just enjoyed Easter services with the local people and it was wonderful at the little yellow church in the village. It really is a special place set  near  the last hawaiian fishing village\r\n",
#    'host_response_time': 'within an hour',
#    'host_thumbnail_url': 'https://a0.muscache.com/im/users/6017048/profile_pic/1387948340/original.jpg?aki_policy=profile_small',
#    'host_picture_url': 'https://a0.muscache.com/im/users/6017048/profile_pic/1387948340/original.jpg?aki_policy=profile_x_medium',
#    'host_neighbourhood': 'Island of Hawaiʻi',
#    'host_response_rate': 100,
#    'host_is_superhost': True,
#    'host_has_profile_pic': True,
#    'host_identity_verified': True,
#    'host_listings_count': 2,
#    'host_total_listings_count': 2,
#    'host_verifications': ['email', 'phone', 'reviews', 'kba', 'work_email']},
#   'address': {'street': 'Captain Cook, HI, United States',
#    'suburb': 'Island of Hawaiʻi',
#    'government_area': 'South Kona',
#    'market': 'The Big Island',
#    'country': 'United States',
#    'country_code': 'US',
#    'location': {'type': 'Point',
#     'coordinates': [-155.89926, 19.20636],
#     'is_location_exact': True}},
#   'availability': {'availability_30': 5,
#    'availability_60': 21,
#    'availability_90': 40,
#    'availability_365': 215},
#   'review_scores': {'review_scores_accuracy': 10,
#    'review_scores_cleanliness': 10,
#    'review_scores_checkin': 10,
#    'review_scores_communication': 10,
#    'review_scores_location': 9,
#    'review_scores_value': 10,
#    'review_scores_rating': 97},
#   'reviews': [{'_id': '8239390',
#     'date': datetime.datetime(2013, 10, 21, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '5868092',
#     'reviewer_name': 'Yury',
#     'comments': 'Our stay at Aloha Beach House was very nice. It really looks like on the pictures. The house is equipped with a lot of stuff that one might ever need for vacation: kayaks, tennis table, board games, TV with Netflix subscription, freezer with ice maker, etc.\r\n\r\nLynn, the house manager, was very welcoming and helpful. She made a nice intro when we arrived and tried to do whatever necessary to make our stay more pleasant. When we found ants in the kitchen, we told Lynn, and the next day the problem was solved.\r\n\r\nThe drawback I can think of is the lack of sound proofness, so when somebody goes to a bathroom it can be heard from the neighboring room. It was not a big deal though, since we rented the whole house.\r\n\r\nWe really enjoyed our stay at Aloha Beach House. Thank you, Cheryl and Lynn!!\r\n'},
#    {'_id': '9008719',
#     'date': datetime.datetime(2013, 12, 1, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '8298993',
#     'reviewer_name': 'Phil',
#     'comments': "If you ever wanted to stay in a lava-field - THAT's the place to stay - the atmosphere around the house is just so special and one of the quitest places i've ever been - cheryl makes sure that you'll get all the informations you need and makes everything that you feel at home - a bbq on the huuuuge lanai is a must!!!"},
#    {'_id': '9194211',
#     'date': datetime.datetime(2013, 12, 12, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '9234335',
#     'reviewer_name': 'LoriAnn',
#     'comments': "We had a wonderful stay at Cheryl's Aloha Beach House.  The house is FULLY stocked with anything imaginable, including coolers, kayaks, snorkels, linens, and even coffee! We found the location to be a great launching point to go to Kona and Hilo.  The house is situated near a historic fishing village and is on a lava field in a quiet community.  Don't let the trip down from the highway intimidate you, just take it slow, the end result is so worth the few miles of curvy road.  The view of the Pacific was amazing!  Cheryl and Lynn were so accommodating and even worked with us so we could stay an extra night.  They provided tips on where to go and helped orient us to the island.  When we come back to the Big Island, we will definitely stay at the Aloha Beach House.  We hope to be back soon. "},
#    {'_id': '9347217',
#     'date': datetime.datetime(2013, 12, 23, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '6743706',
#     'reviewer_name': 'Sophie',
#     'comments': "My parents, my husband and I had a great stay at Cheryl's house. It's very clean and cozy. It looks exactly like the picture or even better. We could see the ocean from the living room and the kitchen. There is a huge collection of movies and games too. Lynn, the manager, is very nice and helpful. She gave us some very good information for us to plan our trip and shared some great storied from her own experience. She recommend an awesome bakery on our way to the volcano park. She also helped fix the TV promptly. The location is a little far from the popular area. But it was not a issue for us since my husband is a good driver and the view from the house and the house itself just offset the little inconvenience. We recommend this place to anyone who want to visit the big island and we hope to visit again the next time."},
#    {'_id': '9522701',
#     'date': datetime.datetime(2014, 1, 1, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '10156884',
#     'reviewer_name': 'Meena',
#     'comments': 'Thank you Cheryl and Lynn for your beautifully decorated and cozy beach side abode! :) It was a great vacation spot. Would recommend for families or groups of tourists looking for an isolated but picturesque place to stay :)'},
#    {'_id': '9782981',
#     'date': datetime.datetime(2014, 1, 10, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '7428458',
#     'reviewer_name': 'Maia',
#     'comments': 'Aloha Beach House was in a beautiful, quiet setting on a lava field.  A bit off the beaten path- but exactly as pictured.  Three bedroom three bath gives everyone some privacy.  The downstairs bed/bath was my favorite because I could hear the ocean waves crashing.  The hosts have just about everything!  DVDs, Netflix, ice chests, boogie boards, kayaks.  They have a rec room with table tennis and pool table.  The outdoor lanai is great for BBQs and watching sunsets.  Great hosts- very prompt with communications and manager was around daily to answer questions.  About an hour from Kona and an hour and a half from Volcano.'},
#    {'_id': '9862516',
#     'date': datetime.datetime(2014, 1, 15, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '95009',
#     'reviewer_name': 'Carsten',
#     'comments': "Very nice house with an excellent view to the ocean. The property is designed and equipped for rentals. You'll even find snorkeling gear, finns and beach shoes. \r\nI can definitely recommend this place."},
#    {'_id': '9916521',
#     'date': datetime.datetime(2014, 1, 19, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '10949957',
#     'reviewer_name': 'Elizabeth',
#     'comments': 'This house is a HOME! And I felt so lucky to be able to share it! Thank you Cheryl and Lynn! For those of you who have never been to the Big Island, it is not the white sand beaches of postcards - but it is AMAZINGLY beautiful. This house sits in a field of lava overlooking dramatic cliffs. The drive down the hill is not for someone like my other (who is terrified of hights) but I loved driving it.  One of the best beaches on the island is only a 10 minute drive and 20 minute hike away, but be aware, you all have to drive to anywhere on this island. We brought some clothing detergent and left it and some salt and paper, we also left a card for the Big Island Chocolate Store frequent buyer card so the next people can take advantage of it and get some free chocolate. Spread the love if you come!'},
#    {'_id': '10226345',
#     'date': datetime.datetime(2014, 2, 7, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '8884057',
#     'reviewer_name': 'Liam',
#     'comments': "Lovely property in remote area. Perfect if you are looking to get away as there are no stores within a half hour radius. We didn't actually end up staying at the house as were wanted to be around people, beaches, clubs, restaurants and bars. Lynn, the property manager was very helpful and Cheryl, the owner was very understanding in allowing us to leave without penalty. \r\nPros: \r\nBig spacious house with panoramic deck.\r\nBike, pool table and washer/dryer in basement. \r\nNice view of the water \r\nNeat interior design \r\nWhale Watching 30 seconds from house \r\n45min -1hr from South Point, Green/Black Sand Beach\r\nCons: \r\nNo stores nearby, takes 15 min to drive up the hill\r\nPay for Wifi\r\nTV is Roku, not live \r\nNo AC, But fans in each room and breeze from outside \r\nA lot of mosquitoes in the area.\r\n\r\nOverall, I really liked the house itself but not so much the area. \r\nHowever, it really depends on what kind of vacation you are looking for. \r\n \r\nThank You Cheryl"},
#    {'_id': '10758208',
#     'date': datetime.datetime(2014, 3, 6, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '6582377',
#     'reviewer_name': 'Andrea',
#     'comments': "We had a lovely time at Cheryl's house to celebrate my parents' 50th anniversary (she even arranged a bottle of wine, which was a very thoughtful touch!).  The house is really beautiful and is exactly as described and pictured.  Lynn, the manager, was very nice and accommodating. \r\n\r\nBe sure to follow the recommendations from Cheryl and the other reviewers.  Bring your food and drinks with you and be careful in planning your outings so you don't have to go up and down the hill too many times.  I was terrified driving down the hill for the first time (despite the breathtaking views!) b/c I was convinced we'd never get our rental minivan back up the switchbacks on the winding narrow road, but it really wasn't a problem."},
#    {'_id': '10875093',
#     'date': datetime.datetime(2014, 3, 11, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '5003910',
#     'reviewer_name': 'Helen',
#     'comments': 'great house, great location, amazing view of the ocean, beautiful stargazing at night. we had a fantastic stay. wish i was still sitting out on the lanai. thanks cheryl!'},
#    {'_id': '12721031',
#     'date': datetime.datetime(2014, 5, 9, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '1640453',
#     'reviewer_name': 'Everett',
#     'comments': 'Pros:\r\nCheryl and her manager Lynn were both very communicative and kind. The house was clean and spacious, had a wide deck, and plenty of snorkel/ocean gear. The neighborhood is very quiet and the houses set apart. Homolino beach is a short drive and mild walk away, and is very secluded and beautiful.\r\n\r\nCons:\r\nThe property is on a big lava flow area, which is a cool vibe (feels like Mars) but not a lush part of Hawaii. Also, the swim/snorkel area 1.5 blocks away is not a beach (its a rocky lava shore) and not the safest feeling -- Homolino is great though, as are other places you can drive to. Finally, Cheryl openly admits this, but it is really far from stores, restaurants, etc (30-60m depending). Just things to keep in mind.'},
#    {'_id': '12922291',
#     'date': datetime.datetime(2014, 5, 14, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '9052083',
#     'reviewer_name': 'Devon',
#     'comments': "The house was great. Very clean and spacious. Beautiful ocean views and falling asleep to the sound of the waves every night cannot be beat! The location is really unique and amazing. \r\n\r\nIt was in a nice, secluded neighborhood with fairly easy access to local beaches. The south end of the island is a beautiful place to explore, especially if you are looking for a relaxing, quiet vacation away from the traditional touristy Hawaii.\r\n\r\nThe road down to the house was a bit steep and winding, but it's well paved and we didn't have any issues. It does take a bit of time to get in or out of the neighborhood on this road since you have to drive slow.\r\n\r\nCommunication with the host was prompt, friendly, and helpful. Very easy to communicate back and forth with any questions we had during our stay."},
#    {'_id': '13647768',
#     'date': datetime.datetime(2014, 6, 2, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '6562329',
#     'reviewer_name': 'Petr',
#     'comments': "Cheryl, thank you very much for this vacation. Very nice house. Lots of space, huge lanai. Coral fish 5 minutes by walk from the house. Free to use: snorkling gear, washer and dryer, stove, fridge with ice maker... everything works fine. House is located in secluded location right at the ocean. Island itself is amazing: we drove everywhere: Waipio valley (twice!), Waimea, Hapuna beach (nice sand beach), Kahaluu beach (best snorkling beach), Hookena beach, Hilo, Kona, waterfalls,  Volcano park, Mauna Kea. Dolphin tour is must see! Only thing is that house does not have A/C (still have lots of fans in every room), so if  you stay in the house all day it might be little uncomfortable (at least it was for us those 2 days we did not go anywhere), but you won't find A/C in most places anyway.  \r\nIt was the best vacation we have ever had! Thank you! P.S Mangos are delicous in Hawaii! Ate them everyday, never got tired!"},
#    {'_id': '14686434',
#     'date': datetime.datetime(2014, 6, 24, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '3340675',
#     'reviewer_name': 'Carey',
#     'comments': "Second time staying at the Aloha Beach House and will book again for the next trip to The Big Island. Wonderful retreat from the typical touristy places and easy to get to. Easy drive from Kona Airport with a quick stop at Target (or Wal-Mart across the highway) for food supplies before driving south to Miloli'i. We always stop at the South Kona Fruit Stand for smoothies before arriving at the Aloha Beach House. Amazing snorkeling in Honomalino Bay (get there early and you'll be treated to hours of entertainment by dolphins with no one else around). Quick drive over to Volcano National Park and super easy to all other attractions the Big Island has to offer. When you return to the Beach House, fire up the grill for dinner and enjoy your delicious Hawaiian meal on the deck. The Beach House is comfortable year-round, even without A/C (we've stayed in March and June). Don't miss the phenomenal sunsets that can be seen from the deck, as well as from inside! "},
#    {'_id': '15405991',
#     'date': datetime.datetime(2014, 7, 8, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '16044770',
#     'reviewer_name': 'Jens',
#     'comments': "We (family with three young kids) just had some wonderful days at Aloha Beach. The house has lots of space, it's very clean, fully equipped with everything and the terrace provides an amazing view over the sea. We loved to snorkel and see an amazing colorful underwater world only 2 min away from the house. We would come back anytime. If you don't look for overcrowded places and beaches we can strongly recommend to stay there for quite and relaxing holidays"},
#    {'_id': '16440244',
#     'date': datetime.datetime(2014, 7, 27, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '13994783',
#     'reviewer_name': 'Clinton',
#     'comments': "What a wonderful house!  Cheryl's place is clean, comfortable, spacious and comes with amazing views from the wraparound deck.  A quick walk down the road and you're in the water swimming, snorkeling or kayaking in what might as well be your own private cove on the Big Island.  If you're looking for a nice quiet place to relax and slow things down this is a great place to do it.  "},
#    {'_id': '17993078',
#     'date': datetime.datetime(2014, 8, 20, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '10741411',
#     'reviewer_name': 'Sophie',
#     'comments': "We had a fantastic time at the Aloha Beach House. The welcome was warm with Daniel looking after us and showing us the kayaks and beach gear (which we put to good use around the bays near Captain Cook). The design of the house allows for some fantastic sea breezes meaning we didn't over heat and some of the best snorkelling was just down the road in the bay itself! The house is very comfortable and well stocked with dvds and netflix. A very relaxing stay and a definite recommendation!"},
#    {'_id': '19266487',
#     'date': datetime.datetime(2014, 9, 9, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '3434228',
#     'reviewer_name': 'Anna',
#     'comments': 'Our stay at the aloha beach house was just wonderful.  The house was well appointed; we had everything we needed and more, with attentive care from both our hosts and from Daniel, who lives next door and was just a phone call away.  The house was surprisingly cool with all the sliding glass doors and fans.  Even after being closed up in the heat, it cooled off quickly upon our return in the evening.  We loved the location, since it was off the beaten path, giving us easy access to explore places that may not be seen by most visitors to the big island.  We loved jumping in the water first thing in the morning.  There is an easy place to hop in and enjoy world class snorkeling just a two minute walk away, and with snorkel gear provided, as well as boogie boards and kayaks, exploration is a must.  We highly recommend this house to anyone looking for a vacation away from the resorts and standard tourist fare.  Although we were two couples, it was obvious the house would be great for kids and adults alike.  Thanks, Cheryl, for making our stay on the big island memorable and relaxing.'},
#    {'_id': '19364470',
#     'date': datetime.datetime(2014, 9, 11, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '3458299',
#     'reviewer_name': 'Jessica',
#     'comments': 'Comfort. Awesome views. Quiet.\n\nThese are the things we were looking for after nearly two weeks of active exploring. \n\nWe would love to come back.\n\nTips: there is plenty of cooking oil, basic spices, coffee/tea and drinking water. Groceries are 30 mins away so stock up. If the swimming hole is too deep/rough, head north down the main road to great wading and snorkeling.'},
#    {'_id': '19517513',
#     'date': datetime.datetime(2014, 9, 14, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '12904668',
#     'reviewer_name': 'Karoline',
#     'comments': "The house is wonderful! Nicely furnished, lots of space. A quiet and peaceful place! We loved the ocean view. It's only a 5 min. walk to a bay where you can snorkel. Cheryl was very helpful although she doesn't live in the area."},
#    {'_id': '21698160',
#     'date': datetime.datetime(2014, 10, 22, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '15541635',
#     'reviewer_name': 'Jake',
#     'comments': "The house was nice! We had fun playing games in the basement (having a washing machine on our trip was also a bonus) and settling down to some netflix after a long day's adventures to relax with the screen doors open.\r\nThe swimming area is neat (it is not a beach, but a rocky area you walk down directly to the water and has a home-made bridge and railing to keep your balance) and all the snorkeling equipment is available with the rental!\r\nThe biggest issue with the house is that it is located at the bottom of a large hill/cliff with very, very steep roads. We didn't mind driving a while to the nearby towns (Kona is ~1 hour away) but the road down to the house is pretty rough and at points it's nearly 1 lane wide, which is a little scary when there are also other people trying to get up or down the hill. It also takes about 15-20 minutes to drive up or down it. Yikes!\r\nAll in all, we had a good time at the house. Mahalo!"},
#    {'_id': '23572097',
#     'date': datetime.datetime(2014, 12, 5, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '21381254',
#     'reviewer_name': 'Emma',
#     'comments': "The house is fabulous, Cheryl is a great host, the location wasn't for us. \r\n\r\nCheryl was a great host. Good communications, and friendly. Great to have bottled water supplied in the heat of Hawaii! \r\n\r\nThe house is amazing. Spacious, comfy, well equipped. A fantastic holiday home for a couple getting away, a group having an adventure, or a family spending time together. The kind of house you could settle into for a few weeks, and not feel cramped. \r\n\r\nThe location is good in some ways. It is between Kona and the volcano, which means you could explore in either direction. But it wasn't what we were looking for. I should have done more research. \r\n\r\nWe wanted surf, easy swimming, and not a lot of driving. We were only in Hawaii for five days, and wanted some R&R. We couldn't easily access the water from here, and needed to drive to explore. Other reviewers didn't seem to have this problem, and certainly the guest book in the host was full of glowing reviews from people who had a great time and swam nearby very happily. \r\n\r\nWe actually ended up leaving after one night, instead of the booked three. Only because we didn't do enough research before booking, and the location didn't suit us. As I said, the house is great, Cheryl is great, and the location will suit some people really well. Just not us. "},
#    {'_id': '24135327',
#     'date': datetime.datetime(2014, 12, 21, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '21969068',
#     'reviewer_name': 'Ben',
#     'comments': "The house was just as beautiful and comfortable as we'd expected! And even more spacious than it looks online. Daniel the neighbor came by to tell us about the best spots to visit in the area. The house (and the whole neighborhood) is on one big lava flow. There is next to no traffic and also next to no lights at night, which made for incredible star gazing. I could spend forever sleeping to the sound of the surf from this house! Honomalino Beach (just a short drive and hike from the house) was the best, most private beach we visited on the Big Island. And the house is stocked with all the beach toys you could need! The game room looked fun, but we were too busy having fun outside to ever use it. Can't wait to go back!"},
#    {'_id': '25398329',
#     'date': datetime.datetime(2015, 1, 14, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '664964',
#     'reviewer_name': 'Brian',
#     'comments': "It is all about the Toilet paper. \r\n\r\nIf you don't read anything else in this review, understand that the toilet paper provided at the Makai Hideaway is really good quality paper, it exemplifies the attention to detail that Cheryl put into her home, and the hospitality in the small details that makes a big difference between just a rental and an amazing home. \r\n-----\r\nWe loved our stay at Cheryl's place! We felt incredibly privileged that she shares her wonderful home. \r\n\r\nFirst, the location: One of the things that the Big Island is known for is its volcanoes and lava. Other than seeing actual flowing lava (which wasn't possible during our stay), one can pretty much experience the same at the seaside house. The house is on actual lava flow and one can see and experience the lava field the community is built upon. In addition, one can see and hear the ocean and the beautiful coastline from the house. There is a small black sand beach less than 20 minutes away as well as another swimming/snorkeling location less than 5 minutes (walking!) away. In short, the location is beautiful!\r\n\r\nHospitality: It is the little things that count: an up-to-date 2014 travel guide for the Big Island that we brought with us on our daily excursions, Hawaiian music CDs, DVDs, wifi, kitchen utensils, bowls and everything else you'd need to cook, laundry room, game room, water fun activity stuff...we really couldn't have asked for anything more during our stay. \r\n\r\nThe process: Cheryl was very responsive to our request to book, even though we contacted her last minute. She is very friendly and answered all of our questions promptly. Her directions were excellent, we had no problem finding the house at night. Daniel the local caretaker is a fount of local information, providing tips on what is worth the time and money and what is just a tourist trap. \r\n\r\nOther miscellaneous thoughts: the house is a ways away from the main tourist area of Kona, which is great because you can enjoy your stay away from tourists. Also, the house is great value to share with some friends as there are plenty of sleeping places. \r\n"},
#    {'_id': '26175667',
#     'date': datetime.datetime(2015, 2, 6, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '21506963',
#     'reviewer_name': 'Nicholas',
#     'comments': "We loved the house!  Plenty of space to sit and relax (although we were usually out and about) and the extra goodies (kayaks, snorkeling gear, boogie boards) were so great to have.  Don't worry about bringing snorkel gear as there are about ten full sets.\n\nAs previous reviews suggested, the house is a bit out of the way (roughly an hour south of Kona and fifteen minutes down a winding road of switchbacks).  This was not too big a deal for us since it's the Big Island and we knew we would be doing a lot of driving.\n\nThere are four beds in the house and a few additional sleeping spaces (a futon, air mattress, and sofa bed).  We had 8 adults, and not all were couples, so it was a tad constricting.  One was in the futon and another in the air mattress.  Not too bad for the week we were there, but any additional time might have seemed cramped.\n\nCheryl is great at communication leading up to the trip.  I had several questions and she usually responded within minutes.\n\nDaniel, who watches over the house since Cheryl doesn't live in the area, is a treasure trove of information.  He is very fun and loves to help with any planning.\n\nOverall, I highly recommend the house.  Just make sure it is the right fit for your size group and what you're wanting to do."},
#    {'_id': '26515772',
#     'date': datetime.datetime(2015, 2, 15, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '20168389',
#     'reviewer_name': 'Lee',
#     'comments': "We thoroughly enjoyed our family reunion at Aloha Beach House. There were 3 bedrooms and 3 bathrooms, and a full kitchen. We stocked up food at Costco & Choicemart, and ate gourmet meals every night. The lanai is large and comfy, and with fans and the breeze we didn't need AC.  Miloli is in a fairly isolated location, but that also is a positive if you aren't looking for hordes of tourists (we weren't), and it is much closer to the Volcano Park than other places on the Kona side. Cheryl was great to work with and very attentive to our needs. Daniel the host is very welcoming, and so are the other neighbors. The ocean is fabulous there, crashing surf vs.lava.  The house is accommodating and comfy, and cutely decorated. The ping-pong table was well-used by us, as was the kitchen.  The price was very reasonable for everything provided.  Overall, a great week - thanks, Cheryl ! "},
#    {'_id': '26854449',
#     'date': datetime.datetime(2015, 2, 21, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '4128675',
#     'reviewer_name': 'Alexandra',
#     'comments': 'Cheryl was very accommodating  and made us feel very welcome at her house.  We needed a playpen for our baby and she made sure it was there when we arrived.  The house was very clean and had plenty of games, such as ping pong table and billiard/hockey table to occupy all of our 4 kids.  There was also lots of water gear which we were grateful to have for our trips to the beach.  We especially enjoyed the spacious lanai where we had all our meals.  The house has a great view of the ocean and we were able to watch wales breaching in the evenings through binoculars provided by Cheryl.  It is a very comfortable house and there is always a nice cooling breeze on the lanai.  '},
#    {'_id': '27394469',
#     'date': datetime.datetime(2015, 3, 3, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '6798212',
#     'reviewer_name': 'Irina',
#     'comments': 'We felt like we are at our summer house. It has everything for comfortable stay and even more. We liked the place, sunny, close to the ocean (no sandy beach like everywhere on Big Island, but good enough to swim), just 100 meters from rocky steps to the ocean. One thing made us upset - this place is really far from everything and to get there you drive from the highway down along mountain serpentine for 5 miles. For a short stay is not convenient, good for a long relaxing vacation.'},
#    {'_id': '27710142',
#     'date': datetime.datetime(2015, 3, 10, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '21467305',
#     'reviewer_name': 'Ron',
#     'comments': 'Cheryl was an excellent host. She kept us informed via email as to what was going on, lava flow activity, and general weather. We had zero problems.\r\n\r\nThe house itself is great. While there were only four of us on this trip, the house could easily accommodate twice that many. The beds were comfortable, the bathrooms well stocked with shampoo, soap, sunscreen, ointments, etc., and the view of the ocean off the front lanai was excellent.\r\n\r\nThe kitchen is well stocked with everything you need to make good food, and the living area has comfortable furniture and even amenities like Netflix.\r\n\r\nThe caretaker, "Uncle" Dan, was friendly and outgoing. He is also a fount of local information, and he gave us directions to an excellent local beach. This beach is hard to get to, but is fantastic.\r\n\r\nThe house also has just about everything you need for an island stay: many pairs of snorkels and flippers, kayaks, body boards, water shoes, and numerous other stuff to make your stay pleasant. The fact that you are a one minute walk from excellent snorkeling in the bay doesn\'t, hurt, either.\r\n\r\nThe listing is very accurate, and the photos match the house. The house itself is very nicely appointed with nice art and colours. It didn\'t feel like we were invading anyone\'s personal space, and it was very comfortable.\r\n\r\nThe only "drawback" has more to do with the island itself than the house. It is fairly remote, and it takes a lot of driving to get anywhere. Not that distances as so far: you can only drive about 35 mph / 60 km/h, so it takes a while to get anywhere. The twisty roads take some getting used to, especially for a Canadian who\'s used to wide open spaces and straight roads. None of this detracts from the house, which was exactly as advertized.\r\n\r\nOverall, the house was what we expected, the hosts were fantastic, and the view of the ocean off the lanai is great. We had an excellent time, and I would recommend this house to anyone who wants to "get away from it all" in a secluded location.'},
#    {'_id': '27971914',
#     'date': datetime.datetime(2015, 3, 15, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '28935124',
#     'reviewer_name': 'Katie',
#     'comments': "Cheryl's home is absolutely gorgeous. It's in a quiet neighborhood with wonderful views of the ocean. We loved spending time in the bright living room surrounded by views of the ocean and on the wrap around balcony. Daniel greeted us and made us feel welcome - he was full of insider knowledge and great tips. \r\n\r\nThe house is at the bottom of a steep and winding road - the drive down from the highway takes 10-15 minutes depending on your comfort. The road is well paved and you do not need a 4 wheel drive.\r\n\r\nEverything you could need for the beach is provided, including snorkel gear and kayaks. Although we didn't have the opportunity to use the kayaks or the snorkel gear because the waves were very rough near the house - I think this is uncommon and was due to a swell passing through. There are 3 good size bedrooms plus a queen bed in the game room. I think the house could comfortably sleep 4 couples plus a couple of children on air mattresses and pull out couches. Note that the game room, bathroom, and large bedroom downstairs are not connected to the main living space upstairs.\r\n\r\nVolcano National Park is about 1 - 1.5 hours away and Hilo can be reached in 2 hours with no traffic, if you really book it (we were late for a flight). Captain Cook is not too far, but the traffic took us nearly an hour. Make sure to bring your own food to the house. All kitchen items are provided.\r\n\r\nWe only wish we could have stayed longer. I think the house is a great place to relax and enjoy the quiet and wonderful view. There are some wonderful hikes nearby and Volcano National Park is not too far. We're hoping to bring our family back."},
#    {'_id': '30490077',
#     'date': datetime.datetime(2015, 4, 23, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '23425018',
#     'reviewer_name': 'Tracey',
#     'comments': "Having Daniel check us in was great. Gave all the pertenant information and giving us some local insite in where to go was an added bonus. By having Cheryl check in a few times before the scheduled arrival it made me feel like she was there and not just a hotel that you check in/out and thats it. Cheryl you made it a very personal experience and that is nice. Thank you.  I think the only description that I either missed or was not there was just the windy roads to mile marker 89 and the 3 miles down to the subdivision. I am very glad we arrived in daylight as the road could have been a  little scary in the dark first time round. Some people may not enjoy those trips daily up/down that road. Might be nice as a heads up for potential guests. Just a thought. The sunsets views as well as the sunrises were incredible. That was spot on. The neighborhood was very quiet and felt really safe there (when we were there). I think the place was fantastic. I sure hope that the new houses going up don't affect the view but really unless it is a high rise the views will still be spectacular. Location was great. Close to Volcano, South Point and  getting to Hilo. It was also great heading back into Kona. Windy roads definitely slow travel down but gets you to look at all the local land. We did not even have to spend money on snorkeling trips as we had enough gear and enough beaches to go do it ourselves. Tons of dolphins within feet of us. Turtles. Many fishes and we believe one small shark! I mean the beauty was everywhere. Just know that the beaches nearby are not your typical sandy white beaches but beautiful in their own special ways. Make a point to eat local kine foods. Markets, fruit/vege stands all over. Fresh fish. Cook at the house....We had a few of our best meals at home and local grown foods. No paid for luau needed. I got to eat poi daily. ONOLICIOUS! Mahalo nui Cheryl for a beautiful comfortable home and the most perfect lanai. Until next time. "},
#    {'_id': '30795439',
#     'date': datetime.datetime(2015, 4, 27, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '30106698',
#     'reviewer_name': 'Ryan',
#     'comments': "The experience overall was wonderful!  The house was amazing and alot of fun.  They had everything there you could think of for the stay including water toys, fishing gear, etc.  Saved alot of money from having to rent everything.  I would definitely go back and visit again in the future.  The location was a little out there but that's actually what we preferred, was to be away from all the tourists.   But overall it is in a great spot because you can venture around the island in either direction and see it all.  Thanks again for the amazing experience!"},
#    {'_id': '32966761',
#     'date': datetime.datetime(2015, 5, 24, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '28653625',
#     'reviewer_name': 'Anqi',
#     'comments': 'Cheryl was very responsive to all my questions. She was also very kind to give us the detailed driving directions upon knowing that we would arrive in the late evening. The house was great! The location is ideal for vacation escapes. The house is quiet, clean and comfortable. We found everything we needed. There are tons of travelling books and brochures about Big Island. We played ping pong and air hockey while waiting for laundry. Dan was very informative. He told us where to buy local food and where to find a quiet beach. We had a lot of fun! We wish we could stay longer!'},
#    {'_id': '35372446',
#     'date': datetime.datetime(2015, 6, 18, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '29874583',
#     'reviewer_name': 'Pascal',
#     'comments': 'It was a very nice stay. The lookout was beautiful and we felt at home. Strongly recommended'},
#    {'_id': '37984722',
#     'date': datetime.datetime(2015, 7, 12, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '12233045',
#     'reviewer_name': 'Alexis',
#     'comments': 'The house is just awesome, you can see right away that is has been furnished with lots of taste.\r\nThe neighborhood is also great, as it very calm and quiet and has very particular atmosphere due to the black lava.\r\nLast, sunsets are just unique: the orange of the sun, the blue from the see, the black of the Lava, what a spectacular view! \r\n\r\nSheryl and Daniel were  super helpful and everything in the house was ready\r\n\r\nThis was really an awesome vacation!'},
#    {'_id': '40077742',
#     'date': datetime.datetime(2015, 7, 28, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '25246886',
#     'reviewer_name': 'Sarah',
#     'comments': "Cheryl is one of the most caring people I've ever met. She made sure that we had everything that we'd need for our trip. The house was fully stocked for fun and the neighborhood was quiet and beautiful."},
#    {'_id': '42522922',
#     'date': datetime.datetime(2015, 8, 14, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '33731921',
#     'reviewer_name': 'Michael',
# ...
#    {'_id': '247827847',
#     'date': datetime.datetime(2018, 3, 29, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '88590833',
#     'reviewer_name': 'Kelly',
#     'comments': 'The deck on this place is lovely. Perfect place to sit and visit with friends. We enjoyed our stay here.'},
#    {'_id': '255214850',
#     'date': datetime.datetime(2018, 4, 19, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '167439459',
#     'reviewer_name': 'Jessica',
#     'comments': "Cheryl's place is a wonderful, quiet and relaxing getaway! Plenty of fans to keep the breeze moving throughout the home. A safe neighborhood where everyone seems to know everyone."},
#    {'_id': '264459724',
#     'date': datetime.datetime(2018, 5, 13, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '15584162',
#     'reviewer_name': 'Nicolas',
#     'comments': 'The house is clean and fully furnished, close to a very nice snorkelling location, great sunsets, kayaks and gear ready to use, close to the volcano and black sand beach :)\n\nDaniel was great welcoming us an giving us many tips! \n\nReally a great place, would recommend it anytime!'},
#    {'_id': '265629232',
#     'date': datetime.datetime(2018, 5, 17, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '166247388',
#     'reviewer_name': 'Ram',
#     'comments': 'This place has beautiful furniture in all rooms. It has good views and is very spacious and classy. My teenage kids were totally impressed with the place and thought it was a great place to hold a party.'},
#    {'_id': '271262557',
#     'date': datetime.datetime(2018, 5, 31, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '182262545',
#     'reviewer_name': 'Jim',
#     'comments': "My visit to the Makai Hideaway was my first time in Hawai’I and my first time on Airbnb. We couldn’t have made a better choice. Cheryl has a beautiful house in a great location. We were 7 adults celebrating my daughter’s college graduation and our 32nd anniversary in May 2018. After we planned the trip, Kilaueua erupted and that made us even more excited to visit. Unfortunately, it also meant vog on our side of the island, eliminating the Fantastic Sunsets part of the equation. But it also meant less direct sun, so much cooler. Cheryl’s house is ideal if you want to get away from the madding crowd, but have access to all the Big Island has to offer. We were out of the house every day by 7am and back in time to make dinner and enjoy each other’s company. Our itinerary included Honomalino Beach, South Point, Discovery Harbor, Green Sand Beach, Punalu'u Black Sand Beach, Hilo, Rainbow Falls, Mauna Kea, Makalawena Beach, Kahalu’u Beach Park, Kealakekua Bay (visit Ehu & Kai Adventures for rentals – family-owned!), Captain Cook monument, and the City of Refuge - Pu'uhonua O Hōnaunau National Historical Park. All with Miloli’I as our home base. It IS 10 minutes off the hwy down a winding road with a 1500-foot drop in elevation, but that’s a good thing to me! There was nothing we needed that wasn’t already in the house, except food, but including spices. The property description is excellent; the house is exactly as described. One thing that I didn’t pick up on is that the water cistern isn’t for drinking water – Cheryl provides that in a couple of water cooler/dispensers with plenty of extra jugs of water. But water became our only problem – more below. Thought we would use the ping pong & pool tables, but no time – we were never in the house. Never turned the TVs on either. The house did get hot after being locked up all day, but it cooled off fast with so many windows and screen doors and fans. Costco IS a sensible first stop before coming to the house. We planned out our meals and got most all the ingredients there. We ended up with too much food though, and took most of the excess over to Pahoa to donate to the Leilani Estates evacuation center. Funny though; we didn’t seem to have an excess of alcohol.  But as with most marvelous properties, everything’s great as long as everything’s great. But what happens when something happens? I think that’s when you find out what kind of host you have. For us, it came on the 7th day- no water came out of the faucets. We let Cheryl & Daniel know, and they immediately went to work trying to find the problem. It turned out we were out of water, which was a little odd since we were fairly conservative on water use and the house has a big tank. But Daniel..."},
#    {'_id': '274669449',
#     'date': datetime.datetime(2018, 6, 9, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '190348075',
#     'reviewer_name': 'Patrick',
#     'comments': 'Great house with a fantastic local black sand beach and wonderful ocean views.  Location is a bit off the beaten path, but it’s much closer to Volcano National Park than Kona and about equidistant to Hilo as Kona is.  Definitely fly into Kona if staying here, but if flying into Hilo be sure to take the southern route by Volcano National Park.  Finally, working with Cheryl is effortless, and the host Daniel is friendly and helpful.  Take Cheryl’s advice and be sure to shop on your way in for necessities.  Closest town with services is about 30 minutes away.  House had everything we could’ve asked for so only pick up food, drinks, etc.  All other amenities are provided.'},
#    {'_id': '282247816',
#     'date': datetime.datetime(2018, 6, 26, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '572560',
#     'reviewer_name': 'David & Joëlle',
#     'comments': "Cheryl's place is decorated with taste and well furbished in anything you would need. We had a wonderful and relaxing time there. Thank you Cheryl!"},
#    {'_id': '285104239',
#     'date': datetime.datetime(2018, 7, 2, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '18122208',
#     'reviewer_name': 'Yiran',
#     'comments': "Cheryl's place is one of the best Airbnbs I have stayed! \nIf you are looking for somewhere calm, peaceful, and cozy, the place is the best choice! The house is very stylish with full amenities.\nI got up at 5:30 am and jogging around the village, street by street in the curvy and hilly roads, about 7 KM in total, which was very beautiful!\nDaniel is very friendly and helpful, he will tell you many secret places where the local goes. Just standing at the beach, you could see dolphins jumping!\nAll my families enjoyed a lot, and will definitely come  again when we travel to the Big Island next time!\n\nThank you Cheryl and Daniel!\n\nYiran"},
#    {'_id': '289637311',
#     'date': datetime.datetime(2018, 7, 12, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '122106856',
#     'reviewer_name': 'Sherrill',
#     'comments': 'It was our very first airbnb and was a great experience. The house was very clean and just as described. Beautiful place to make home for the week.'},
#    {'_id': '304559855',
#     'date': datetime.datetime(2018, 8, 9, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '45828476',
#     'reviewer_name': 'Jeroen',
#     'comments': 'we loved our time in Cheryls place. The sunsets from the lanai are the best and she makes an effort in making you feel at home. Be sure to go swimming with the manta’s, mindblowing experience! '},
#    {'_id': '322682190',
#     'date': datetime.datetime(2018, 9, 13, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '115568584',
#     'reviewer_name': 'Lori',
#     'comments': 'So many good things to say about Cheryl and the house!!  The most outstanding is how generous a host she was from working with us to make a once-in-a-lifetime vacation happen to promptly communicating to sharing so many goodies that let us have extra fun! The house was wonderful with the amazing deck and the location!'},
#    {'_id': '336042562',
#     'date': datetime.datetime(2018, 10, 13, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '28683320',
#     'reviewer_name': 'Seungwoo',
#     'comments': 'This place is like hidden jewel. Super clean 4 bedrooms and 3 restrooms, super wide balcony which provides fantastic view both sunrise and sunset. This house is fully equipped with furnitures (a lot of chairs and sofas and sun beds!!) and a full of kitchen tools. \n\nJust walk away for 1 minute, crystal clear water awaits you. The entry point is a bit tricky but you will never regret once you jump into the water.\n\nThis house is definitely over 5 stars, must-stay if you want to go Kona.'},
#    {'_id': '339698730',
#     'date': datetime.datetime(2018, 10, 21, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '11630791',
#     'reviewer_name': 'Pat',
#     'comments': 'The house is beautiful and the setting is majestic. We had a great time doing our first snorkel at Milolii Beach and everyone in our group got hooked, from the 3-year-old to Grandma! \n\nAnd having all the equipment (snorkels, masks, water shoes, boards) at the house made it so accessible. Can’t thank you enough!\n\nCheryl is a great hostess and Daniel was a welcoming guide. We would definitely stay again if we ever get back to the Big Island!'},
#    {'_id': '343512289',
#     'date': datetime.datetime(2018, 10, 31, 4, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '201438669',
#     'reviewer_name': 'Randy',
#     'comments': 'House is absolutely amazing, with astonishing views!!! Cheryl is so quick with her responses, there are zero worries!! First day you arrive you’ll meet Daniel, trust me when I say listen to his and Cheryl’s Recommendations, cause they will not steer you wrong!! From the beaches and waterfalls to the definite must do manta ray dive!!! Our journey to Hawaii was absolutely amazing cause of the makai hideaway for sure!!!'},
#    {'_id': '345981826',
#     'date': datetime.datetime(2018, 11, 6, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '21228040',
#     'reviewer_name': 'Hector',
#     'comments': 'Un excelente lugar'},
#    {'_id': '347761632',
#     'date': datetime.datetime(2018, 11, 11, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '161732524',
#     'reviewer_name': 'Hoku',
#     'comments': 'Everything went well. We stayed there for two days for an event down at Milolii. The whole house was already opened for us upon arrival and I had to sign a form that Daniel brought personally to the home. There were no sponges to wash dishes but was addressed by owner quickly and the manager Daniel brought them by. Upon arrival the house was extremely hot, like an oven with only 2 fans for the 14 people upstairs and downstairs. By the next morning the house cooled down much and was fine for the rest of our stay. Would recommend adding fans for every room in the future. The water was not drinkable due to the machines spitting out white particles even when we changed bottles so we were lucky we brought our own as this house is on catchment. The house was nicely decorated and very beautiful and mostly clean. It had EVERYTHING we needed from paper plates to fresh coffee and creamer and lots of dishes, dishwasher, towels etc which was a great touch. There was even a cute disco ball, pool table in the living room.  Daniel was kind of strange but didn’t bother us besides check in and we were thankful to Cheryl for her accommodating such a large group and think she really puts thought and time into her airBnB even though she is in the mainland. There is a cliff-ocean view and beautiful starry skies but the beach is a small drive away. All in all we would stay here again and thought the overall experience was great for the reason we stayed.'},
#    {'_id': '348925470',
#     'date': datetime.datetime(2018, 11, 15, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '169237335',
#     'reviewer_name': 'Bin',
#     'comments': '住在这里真正的意义就是Honomalino海滩,一个会让你足够惊喜的黑沙滩,在这里可以感受到真正的夏威夷,人非常少,沙滩很细,非常适合游泳,浮潜和划船,这个沙滩的品质个人感觉在大岛是顶级的｡开车先到Milolii海滩,把车停在篮球场旁边,然后沿着小路徒步十几分钟就到了这个黑沙滩,路上还长了野生的诺丽果｡还有一个彩蛋,就是从房子去公路的路边上有一个自助的水果摊,有香蕉,木瓜和杨桃卖,价格非常便宜,又非常好吃,千万别错过了｡'},
#    {'_id': '357284076',
#     'date': datetime.datetime(2018, 12, 9, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '222614238',
#     'reviewer_name': 'Jeffrey',
#     'comments': "What an incredible place! The house is just plain gorgeous. It is decorated way beyond what you would expect of a rental vacation. You feel like you are staying at a best friend's house. The location is a tropical ocean dream with waves crashing against the shore and impossible numbers of stars at night. I will never forget having coffee on the lania; we just didn't want to leave."},
#    {'_id': '359427592',
#     'date': datetime.datetime(2018, 12, 16, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '225170794',
#     'reviewer_name': 'Hanzhe',
#     'comments': "We had a nice holiday in Cheryl's amazing house. We have found everything we need. The scenary is beautiful. Daniel is kind and humorous. His tips helped us save lots of time and money. I will recommend this house to everyone."},
#    {'_id': '363930268',
#     'date': datetime.datetime(2018, 12, 29, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '52686127',
#     'reviewer_name': 'Kenya',
#     'comments': "Cheryl's house is just as described.  We were a large family gathering for Christmas and it was a wonderful place to be able  to do just that.  It was spacious and clean and offered great amenities for the kids to play as well as what you would need to take to the beach  The morning view was my favorite, very relaxing and beautiful. The kids loved the adventures to the water and discovering hidden gems.  The community has a speed limit of 15 mph with very little traffic so the kids were able to walk and play carefree outside.  This made my 6th trip to Hawaii (first to Kona) and it was simply wonderful. The house is on the south end of the island which is good in regards to proximity to beautiful beaches that are not crowded, including the one by the house past the village (just be prepared for a bit of a hike but it is well worth it when you arrive)  My kids and I managed to make it to 5 different beaches (1 of them 2 x) Our favorite was Punalu'u Black sand beach (sea turtles).  If you want to relax or hike or have an adventure Cheryl's house puts you in the right place to do so."},
#    {'_id': '367441103',
#     'date': datetime.datetime(2019, 1, 4, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '18412256',
#     'reviewer_name': 'Sallie',
#     'comments': "Cheryl is a very friendly hostess. Her home has many amenities that are WONDERFUL like a ping pong table, fuzzball game, binoculars, etc. If you are prepared to be almost on a moon scape (lava) with little vegetation and don't expect that you can swim, snorkel, and kayak nearby you will have a GREAT TIME. Our family did and would recommend this place very highly."},
#    {'_id': '415886562',
#     'date': datetime.datetime(2019, 2, 23, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '13241896',
#     'reviewer_name': 'Jack',
#     'comments': "HELLO  TRAVELERS. A BEAUTIFUL HOME.GREAT  LOCATION AWAY FROM TOWN.BEAUTIFUL VIEW OF THE OCEAN EVERY MORNING.QUIET OUT IN MILOLI' I. JUST WHAT YOU ARE LOOKING FOR. WIFE AND I AND  FRIENDS HAD A GREAT."},
#    {'_id': '418681609',
#     'date': datetime.datetime(2019, 3, 2, 5, 0),
#     'listing_id': '1095174',
#     'reviewer_id': '11666055',
#     'reviewer_name': 'Justin',
#     'comments': 'Cheryl’s home overlooks a beautiful lava rock view of the extremely blue Pacific Ocean.  It was a few minute walk to the ocean, but not necessarily the beach you would consider safe to swim in.  The coast is a cliff made of lava rock and a rope to pull yourself up/down to.  During the times we walked in the morning and evening (in February) the waves were crashing strongly into that coast line so we refrained from getting in.  The home is has a lot of amenities and activities for young families with kids (games, snorkel equipment, movies, etc).  Unfortunately for our stay, the place didn’t appear to be cleaned properly.  With proper cleaning, the place would be charming and perfect for families looking for a quiet place with a view.'}]}]

# %% [markdown]
# ## Problem 4
#
# Find documents in the training.grades collection where:
# ~~~
# 1) "scores.score" array of embedded documents has no value greater than 80
# 2) Sort by "class_id" descending, student_id ascending
# ~~~

# %% [markdown]
# **expected output**
#
#
# ```
# [{'_id': ObjectId(''),
#   'class_id': #,
#   'scores': [{'79': score1, 'type': 'type1'},
#    {'score': 50, 'type': 'type2'},
#    {'score': 60, 'type': 'type3'},
#    {'score': 20, 'type': 'type4'}],
#   'student_id': #}]
# ```

# %%
list(training.grades.find({"scores.score":{"$not":{"$gt":80}}
           
           })

     .sort([('class_id',-1),('student_id',1)]))
# Out:
# [{'_id': ObjectId('56d5f7eb604eb380b0d8d9e6'),
#   'student_id': 28.0,
#   'scores': [{'type': 'exam', 'score': 0.2898348199689482},
#    {'type': 'quiz', 'score': 13.88300815704696},
#    {'type': 'homework', 'score': 61.998362329748836},
#    {'type': 'homework', 'score': 35.69524705901108}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8da5b'),
#   'student_id': 39.0,
#   'scores': [{'type': 'exam', 'score': 35.50038021886465},
#    {'type': 'quiz', 'score': 18.51205358951419},
#    {'type': 'homework', 'score': 51.075637937645766},
#    {'type': 'homework', 'score': 56.9841767400456}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8da95'),
#   'student_id': 45.0,
#   'scores': [{'type': 'exam', 'score': 75.28863056127419},
#    {'type': 'quiz', 'score': 48.386827853498396},
#    {'type': 'homework', 'score': 51.92253021280575},
#    {'type': 'homework', 'score': 25.903378232715802}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8ddfa'),
#   'student_id': 132.0,
#   'scores': [{'type': 'exam', 'score': 8.00790928431777},
#    {'type': 'quiz', 'score': 8.206653831252009},
#    {'type': 'homework', 'score': 74.26177132634145},
#    {'type': 'homework', 'score': 14.687569893698981}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8df0d'),
#   'student_id': 159.0,
#   'scores': [{'type': 'exam', 'score': 76.03273031703388},
#    {'type': 'quiz', 'score': 0.7007039352919131},
#    {'type': 'homework', 'score': 0.5663425594333082},
#    {'type': 'homework', 'score': 63.0395047780575}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8e0a3'),
#   'student_id': 200.0,
#   'scores': [{'type': 'exam', 'score': 64.58591788037637},
#    {'type': 'quiz', 'score': 28.21306364761683},
#    {'type': 'homework', 'score': 41.103391786206586},
#    {'type': 'homework', 'score': 68.02457351116978}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8e7dc'),
#   'student_id': 385.0,
#   'scores': [{'type': 'exam', 'score': 10.896966423137888},
#    {'type': 'quiz', 'score': 52.31305681059285},
#    {'type': 'homework', 'score': 71.92428965020568},
#    {'type': 'homework', 'score': 61.37034970138613}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8e8c8'),
#   'student_id': 409.0,
#   'scores': [{'type': 'exam', 'score': 9.010366165645568},
#    {'type': 'quiz', 'score': 35.477752586919365},
#    {'type': 'homework', 'score': 35.12384315756245},
#    {'type': 'homework', 'score': 74.67544552423792}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8ec2f'),
#   'student_id': 496.0,
#   'scores': [{'type': 'exam', 'score': 32.1566805284554},
#    {'type': 'quiz', 'score': 26.129278984348925},
#    {'type': 'homework', 'score': 5.679454564215902},
#    {'type': 'homework', 'score': 0.7808039661005184}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d8eea5'),
#   'student_id': 559.0,
#   'scores': [{'type': 'exam', 'score': 4.24463776567533},
#    {'type': 'quiz', 'score': 73.8134996257478},
#    {'type': 'homework', 'score': 47.17355616507961},
#    {'type': 'homework', 'score': 23.552258413617132}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d8f925'),
#   'student_id': 827.0,
#   'scores': [{'type': 'exam', 'score': 9.191720187557252},
#    {'type': 'quiz', 'score': 1.9367449548645221},
#    {'type': 'homework', 'score': 54.276157197162966},
#    {'type': 'homework', 'score': 70.5450952910448}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d8fefb'),
#   'student_id': 977.0,
#   'scores': [{'type': 'exam', 'score': 25.735882468881332},
#    {'type': 'quiz', 'score': 13.699360560592188},
#    {'type': 'homework', 'score': 52.52957554271698},
#    {'type': 'homework', 'score': 24.788492089915525}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d90458'),
#   'student_id': 1114.0,
#   'scores': [{'type': 'exam', 'score': 48.81570194723766},
#    {'type': 'quiz', 'score': 29.037882999939335},
#    {'type': 'homework', 'score': 10.61903749545311},
#    {'type': 'homework', 'score': 9.21536542295266}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d90513'),
#   'student_id': 1133.0,
#   'scores': [{'type': 'exam', 'score': 33.95175339331541},
#    {'type': 'quiz', 'score': 70.7626606247275},
#    {'type': 'homework', 'score': 0.9183575771863906},
#    {'type': 'homework', 'score': 28.30442444403363}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d906fd'),
#   'student_id': 1182.0,
#   'scores': [{'type': 'exam', 'score': 40.21441119818695},
#    {'type': 'quiz', 'score': 79.08778949852598},
#    {'type': 'homework', 'score': 10.974252151198572},
#    {'type': 'homework', 'score': 63.76282453605824}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d909d4'),
#   'student_id': 1255.0,
#   'scores': [{'type': 'exam', 'score': 75.21105661253806},
#    {'type': 'quiz', 'score': 72.43258715815458},
#    {'type': 'homework', 'score': 54.681762331030605},
#    {'type': 'homework', 'score': 6.457896050224576}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d9104e'),
#   'student_id': 1420.0,
#   'scores': [{'type': 'exam', 'score': 61.74166145541648},
#    {'type': 'quiz', 'score': 71.13572946439375},
#    {'type': 'homework', 'score': 44.10666124738428},
#    {'type': 'homework', 'score': 0.7966333206595788}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d917b5'),
#   'student_id': 1610.0,
#   'scores': [{'type': 'exam', 'score': 60.810090495238924},
#    {'type': 'quiz', 'score': 54.622975699642},
#    {'type': 'homework', 'score': 40.35726296060788},
#    {'type': 'homework', 'score': 62.952950938321685}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d91871'),
#   'student_id': 1629.0,
#   'scores': [{'type': 'exam', 'score': 39.58383134399324},
#    {'type': 'quiz', 'score': 67.52227041065562},
#    {'type': 'homework', 'score': 48.797742405063936},
#    {'type': 'homework', 'score': 48.80565185088196}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d91f9f'),
#   'student_id': 1812.0,
#   'scores': [{'type': 'exam', 'score': 29.67359745693927},
#    {'type': 'quiz', 'score': 76.07784976398656},
#    {'type': 'homework', 'score': 3.4646069571598437},
#    {'type': 'homework', 'score': 69.01811722082317}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d9201f'),
#   'student_id': 1825.0,
#   'scores': [{'type': 'exam', 'score': 0.4118931669730985},
#    {'type': 'quiz', 'score': 26.904690013599087},
#    {'type': 'homework', 'score': 23.772435055343188},
#    {'type': 'homework', 'score': 51.71352899470276}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d9215a'),
#   'student_id': 1857.0,
#   'scores': [{'type': 'exam', 'score': 71.5294973381012},
#    {'type': 'quiz', 'score': 30.00583478844274},
#    {'type': 'homework', 'score': 39.551858740602874},
#    {'type': 'homework', 'score': 24.724393395750035}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d93296'),
#   'student_id': 2298.0,
#   'scores': [{'type': 'exam', 'score': 62.612299325689705},
#    {'type': 'quiz', 'score': 71.95583098461779},
#    {'type': 'homework', 'score': 72.37989289596258},
#    {'type': 'homework', 'score': 71.85108310759844}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d93958'),
#   'student_id': 2471.0,
#   'scores': [{'type': 'exam', 'score': 67.55093169678831},
#    {'type': 'quiz', 'score': 0.23968194022738754},
#    {'type': 'homework', 'score': 7.994399713801159},
#    {'type': 'homework', 'score': 35.71268062099185}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d93b2c'),
#   'student_id': 2518.0,
#   'scores': [{'type': 'exam', 'score': 68.29127256396457},
#    {'type': 'quiz', 'score': 22.86104467518132},
#    {'type': 'homework', 'score': 71.11519544723318},
#    {'type': 'homework', 'score': 18.383640156393533}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d94254'),
#   'student_id': 2701.0,
#   'scores': [{'type': 'exam', 'score': 21.37210116460606},
#    {'type': 'quiz', 'score': 32.448359373281356},
#    {'type': 'homework', 'score': 4.705592623811516},
#    {'type': 'homework', 'score': 13.510595738403886}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d94799'),
#   'student_id': 2836.0,
#   'scores': [{'type': 'exam', 'score': 68.30427023115976},
#    {'type': 'quiz', 'score': 55.57975797435466},
#    {'type': 'homework', 'score': 2.707873969152108},
#    {'type': 'homework', 'score': 13.376388916263393}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d94966'),
#   'student_id': 2882.0,
#   'scores': [{'type': 'exam', 'score': 68.95686050080148},
#    {'type': 'quiz', 'score': 73.53310944316999},
#    {'type': 'homework', 'score': 33.95194805307774},
#    {'type': 'homework', 'score': 15.760656351337888}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d94ca2'),
#   'student_id': 2965.0,
#   'scores': [{'type': 'exam', 'score': 65.23729539923703},
#    {'type': 'quiz', 'score': 34.88830534523297},
#    {'type': 'homework', 'score': 26.549840717227337},
#    {'type': 'homework', 'score': 37.390455768186}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d95092'),
#   'student_id': 3066.0,
#   'scores': [{'type': 'exam', 'score': 29.514622058442708},
#    {'type': 'quiz', 'score': 59.98517510907176},
#    {'type': 'homework', 'score': 2.440623083712179},
#    {'type': 'homework', 'score': 73.6485779500287}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d95446'),
#   'student_id': 3160.0,
#   'scores': [{'type': 'exam', 'score': 70.58210092605015},
#    {'type': 'quiz', 'score': 16.962469570153605},
#    {'type': 'homework', 'score': 74.42791800007875},
#    {'type': 'homework', 'score': 62.43070587724595}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d95cad'),
#   'student_id': 3375.0,
#   'scores': [{'type': 'exam', 'score': 34.504908702166205},
#    {'type': 'quiz', 'score': 77.12281851002243},
#    {'type': 'homework', 'score': 58.07934006344265},
#    {'type': 'homework', 'score': 49.65134498530364}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d96866'),
#   'student_id': 3676.0,
#   'scores': [{'type': 'exam', 'score': 8.013730032333498},
#    {'type': 'quiz', 'score': 43.69717094544002},
#    {'type': 'homework', 'score': 19.87143500389117},
#    {'type': 'homework', 'score': 7.248727569565383}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d968b8'),
#   'student_id': 3684.0,
#   'scores': [{'type': 'exam', 'score': 12.944609406429187},
#    {'type': 'quiz', 'score': 54.26189642458169},
#    {'type': 'homework', 'score': 27.406022426316547},
#    {'type': 'homework', 'score': 70.8575467597782}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d96ba7'),
#   'student_id': 3759.0,
#   'scores': [{'type': 'exam', 'score': 78.8496426336404},
#    {'type': 'quiz', 'score': 60.5126933230389},
#    {'type': 'homework', 'score': 32.23307147969455},
#    {'type': 'homework', 'score': 61.322351284507505}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d96bcc'),
#   'student_id': 3763.0,
#   'scores': [{'type': 'exam', 'score': 3.076613986883414},
#    {'type': 'quiz', 'score': 39.835545215172075},
#    {'type': 'homework', 'score': 20.547854907626505},
#    {'type': 'homework', 'score': 71.94350641213167}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d96cce'),
#   'student_id': 3788.0,
#   'scores': [{'type': 'exam', 'score': 61.56954674106145},
#    {'type': 'quiz', 'score': 67.52814975697852},
#    {'type': 'homework', 'score': 6.5064464923227705},
#    {'type': 'homework', 'score': 22.205468730865896}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d96ee6'),
#   'student_id': 3842.0,
#   'scores': [{'type': 'exam', 'score': 73.06653636646155},
#    {'type': 'quiz', 'score': 64.24992683276042},
#    {'type': 'homework', 'score': 0.628619224648197},
#    {'type': 'homework', 'score': 42.37001846515547}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d97da8'),
#   'student_id': 4220.0,
#   'scores': [{'type': 'exam', 'score': 32.81169994971865},
#    {'type': 'quiz', 'score': 58.18779475536269},
#    {'type': 'homework', 'score': 55.366105136927445},
#    {'type': 'homework', 'score': 28.802291887222342}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d97f2c'),
#   'student_id': 4259.0,
#   'scores': [{'type': 'exam', 'score': 72.7656870072012},
#    {'type': 'quiz', 'score': 2.3674037629948796},
#    {'type': 'homework', 'score': 43.751450941412564},
#    {'type': 'homework', 'score': 15.481015366499108}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d980a2'),
#   'student_id': 4296.0,
#   'scores': [{'type': 'exam', 'score': 5.877188083677309},
#    {'type': 'quiz', 'score': 49.74880554625592},
#    {'type': 'homework', 'score': 65.5366604140137},
#    {'type': 'homework', 'score': 18.659715572452697}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d98731'),
#   'student_id': 4464.0,
#   'scores': [{'type': 'exam', 'score': 64.47352065702057},
#    {'type': 'quiz', 'score': 9.241084484413808},
#    {'type': 'homework', 'score': 35.62562680516791},
#    {'type': 'homework', 'score': 40.99452313817204}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d988c8'),
#   'student_id': 4505.0,
#   'scores': [{'type': 'exam', 'score': 64.49964701061162},
#    {'type': 'quiz', 'score': 75.82541082687452},
#    {'type': 'homework', 'score': 28.805810969317324},
#    {'type': 'homework', 'score': 59.273904850033034}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d98bb9'),
#   'student_id': 4580.0,
#   'scores': [{'type': 'exam', 'score': 7.540709679475565},
#    {'type': 'quiz', 'score': 79.9634068941275},
#    {'type': 'homework', 'score': 41.32946650816115},
#    {'type': 'homework', 'score': 21.507603458496305}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d98eab'),
#   'student_id': 4655.0,
#   'scores': [{'type': 'exam', 'score': 76.83125152799066},
#    {'type': 'quiz', 'score': 16.032750996804356},
#    {'type': 'homework', 'score': 29.127017903573616},
#    {'type': 'homework', 'score': 75.89746265787034}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d997ab'),
#   'student_id': 4886.0,
#   'scores': [{'type': 'exam', 'score': 66.56232199827699},
#    {'type': 'quiz', 'score': 73.5638149374299},
#    {'type': 'homework', 'score': 19.827733991193274},
#    {'type': 'homework', 'score': 55.69169862235943}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d99be0'),
#   'student_id': 4993.0,
#   'scores': [{'type': 'exam', 'score': 39.1018106016493},
#    {'type': 'quiz', 'score': 35.402504024485495},
#    {'type': 'homework', 'score': 10.463129139028027},
#    {'type': 'homework', 'score': 38.8190514840263}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d9a2fc'),
#   'student_id': 5175.0,
#   'scores': [{'type': 'exam', 'score': 5.698049653766136},
#    {'type': 'quiz', 'score': 56.03156203946893},
#    {'type': 'homework', 'score': 64.76698349704868},
#    {'type': 'homework', 'score': 55.197531670346166}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d9a40f'),
#   'student_id': 5203.0,
#   'scores': [{'type': 'exam', 'score': 22.62674840223503},
#    {'type': 'quiz', 'score': 56.613857741285024},
#    {'type': 'homework', 'score': 19.802720691298358},
#    {'type': 'homework', 'score': 51.81282892090682}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d9a6dd'),
#   'student_id': 5275.0,
#   'scores': [{'type': 'exam', 'score': 67.61969249679017},
#    {'type': 'quiz', 'score': 51.33448718302118},
#    {'type': 'homework', 'score': 9.220475878384116},
#    {'type': 'homework', 'score': 8.807080674938872}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d9aac7'),
#   'student_id': 5375.0,
#   'scores': [{'type': 'exam', 'score': 13.172926559017506},
#    {'type': 'quiz', 'score': 12.114612370577438},
#    {'type': 'homework', 'score': 79.61438933003365},
#    {'type': 'homework', 'score': 76.42209230090612}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9b3dc'),
#   'student_id': 5607.0,
#   'scores': [{'type': 'exam', 'score': 74.01829447201635},
#    {'type': 'quiz', 'score': 57.908505088981954},
#    {'type': 'homework', 'score': 24.72189693484316},
#    {'type': 'homework', 'score': 49.98023279284226}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9bd5b'),
#   'student_id': 5850.0,
#   'scores': [{'type': 'exam', 'score': 20.838956190886304},
#    {'type': 'quiz', 'score': 20.63999287930568},
#    {'type': 'homework', 'score': 18.20864826908285},
#    {'type': 'homework', 'score': 68.77631354928371}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9bed1'),
#   'student_id': 5888.0,
#   'scores': [{'type': 'exam', 'score': 79.92470069109126},
#    {'type': 'quiz', 'score': 42.0821344854754},
#    {'type': 'homework', 'score': 25.20487729893912},
#    {'type': 'homework', 'score': 63.394407407482625}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9c3b8'),
#   'student_id': 6013.0,
#   'scores': [{'type': 'exam', 'score': 13.05400139386963},
#    {'type': 'quiz', 'score': 70.39857735204866},
#    {'type': 'homework', 'score': 8.528773278951995},
#    {'type': 'homework', 'score': 16.359220557900123}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9c997'),
#   'student_id': 6164.0,
#   'scores': [{'type': 'exam', 'score': 23.77077817069705},
#    {'type': 'quiz', 'score': 78.6242641057152},
#    {'type': 'homework', 'score': 4.4815864458828125},
#    {'type': 'homework', 'score': 47.955570267687264}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9d220'),
#   'student_id': 6382.0,
#   'scores': [{'type': 'exam', 'score': 63.85589692105332},
#    {'type': 'quiz', 'score': 64.29538779524079},
#    {'type': 'homework', 'score': 3.5520985320738108},
#    {'type': 'homework', 'score': 42.88888017682568}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9d6f2'),
#   'student_id': 6506.0,
#   'scores': [{'type': 'exam', 'score': 44.81031748853898},
#    {'type': 'quiz', 'score': 53.32929074456639},
#    {'type': 'homework', 'score': 51.109636974597585},
#    {'type': 'homework', 'score': 63.964858029825535}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9dd3e'),
#   'student_id': 6667.0,
#   'scores': [{'type': 'exam', 'score': 37.93088999692935},
#    {'type': 'quiz', 'score': 16.643087814305837},
#    {'type': 'homework', 'score': 2.3441916029500076},
#    {'type': 'homework', 'score': 54.47167832665008}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9e2f2'),
#   'student_id': 6813.0,
#   'scores': [{'type': 'exam', 'score': 3.281954573230028},
#    {'type': 'quiz', 'score': 73.50388498223363},
#    {'type': 'homework', 'score': 62.94857066711381},
#    {'type': 'homework', 'score': 62.309018375576784}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9e5d2'),
#   'student_id': 6886.0,
#   'scores': [{'type': 'exam', 'score': 70.18516014807263},
#    {'type': 'quiz', 'score': 47.69905282011333},
#    {'type': 'homework', 'score': 13.607667988023609},
#    {'type': 'homework', 'score': 0.021089871601753796}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9e65b'),
#   'student_id': 6900.0,
#   'scores': [{'type': 'exam', 'score': 77.86560411436466},
#    {'type': 'quiz', 'score': 9.447724632536481},
#    {'type': 'homework', 'score': 78.99053025186743},
#    {'type': 'homework', 'score': 48.54987371665662}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9e9f9'),
#   'student_id': 6993.0,
#   'scores': [{'type': 'exam', 'score': 8.115976284392978},
#    {'type': 'quiz', 'score': 1.5589216414617746},
#    {'type': 'homework', 'score': 79.74232885612325},
#    {'type': 'homework', 'score': 50.530568238172705}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0d9eb68'),
#   'student_id': 7029.0,
#   'scores': [{'type': 'exam', 'score': 11.984887194890293},
#    {'type': 'quiz', 'score': 33.60301408085727},
#    {'type': 'homework', 'score': 35.924018080763275},
#    {'type': 'homework', 'score': 45.24182916838498}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0d9ed23'),
#   'student_id': 7074.0,
#   'scores': [{'type': 'exam', 'score': 14.465889960846267},
#    {'type': 'quiz', 'score': 49.185226644706034},
#    {'type': 'homework', 'score': 38.70379389201123},
#    {'type': 'homework', 'score': 62.26780045945176}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0d9f15d'),
#   'student_id': 7182.0,
#   'scores': [{'type': 'exam', 'score': 0.4629035687507499},
#    {'type': 'quiz', 'score': 19.453550826406207},
#    {'type': 'homework', 'score': 14.391710044173568},
#    {'type': 'homework', 'score': 70.17244656720729}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0d9fcfd'),
#   'student_id': 7479.0,
#   'scores': [{'type': 'exam', 'score': 56.9983588284408},
#    {'type': 'quiz', 'score': 62.65502909683479},
#    {'type': 'homework', 'score': 51.00196123914721},
#    {'type': 'homework', 'score': 67.55186100126951}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da014f'),
#   'student_id': 7590.0,
#   'scores': [{'type': 'exam', 'score': 79.28090079023848},
#    {'type': 'quiz', 'score': 4.984283951242774},
#    {'type': 'homework', 'score': 4.63446551358766},
#    {'type': 'homework', 'score': 52.38633629737481}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da0198'),
#   'student_id': 7597.0,
#   'scores': [{'type': 'exam', 'score': 9.4804184513689},
#    {'type': 'quiz', 'score': 53.350220519856606},
#    {'type': 'homework', 'score': 30.601137643596054},
#    {'type': 'homework', 'score': 35.852530311163434}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da0485'),
#   'student_id': 7672.0,
#   'scores': [{'type': 'exam', 'score': 73.6760013208723},
#    {'type': 'quiz', 'score': 72.17286966501497},
#    {'type': 'homework', 'score': 32.511190087438244},
#    {'type': 'homework', 'score': 2.8543547573972816}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da07fe'),
#   'student_id': 7761.0,
#   'scores': [{'type': 'exam', 'score': 10.591128843093534},
#    {'type': 'quiz', 'score': 40.01387904147805},
#    {'type': 'homework', 'score': 3.568383799866659},
#    {'type': 'homework', 'score': 64.16794932709571}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da11da'),
#   'student_id': 8014.0,
#   'scores': [{'type': 'exam', 'score': 63.35318475894843},
#    {'type': 'quiz', 'score': 68.46348880734962},
#    {'type': 'homework', 'score': 40.958459853915095},
#    {'type': 'homework', 'score': 2.9028911333098373}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da1725'),
#   'student_id': 8149.0,
#   'scores': [{'type': 'exam', 'score': 2.2464546924509943},
#    {'type': 'quiz', 'score': 4.231112154663885},
#    {'type': 'homework', 'score': 12.37449423011462},
#    {'type': 'homework', 'score': 16.14674524233871}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da1cfd'),
#   'student_id': 8299.0,
#   'scores': [{'type': 'exam', 'score': 27.032692913390566},
#    {'type': 'quiz', 'score': 71.18388443873458},
#    {'type': 'homework', 'score': 12.176014018408154},
#    {'type': 'homework', 'score': 76.5177434752968}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da1ffd'),
#   'student_id': 8375.0,
#   'scores': [{'type': 'exam', 'score': 0.7774964082716496},
#    {'type': 'quiz', 'score': 56.97871321903267},
#    {'type': 'homework', 'score': 11.10732206194356},
#    {'type': 'homework', 'score': 4.324931068957549}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da20ff'),
#   'student_id': 8401.0,
#   'scores': [{'type': 'exam', 'score': 19.096174444897017},
#    {'type': 'quiz', 'score': 62.78858862044376},
#    {'type': 'homework', 'score': 18.509231585943265},
#    {'type': 'homework', 'score': 71.04619122841437}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da2254'),
#   'student_id': 8435.0,
#   'scores': [{'type': 'exam', 'score': 40.87056177523033},
#    {'type': 'quiz', 'score': 72.37159847773641},
#    {'type': 'homework', 'score': 41.60401698297959},
#    {'type': 'homework', 'score': 58.12997797652354}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da2377'),
#   'student_id': 8464.0,
#   'scores': [{'type': 'exam', 'score': 15.299210614130033},
#    {'type': 'quiz', 'score': 34.0777196568535},
#    {'type': 'homework', 'score': 51.38497292182797},
#    {'type': 'homework', 'score': 31.858676251113472}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da265d'),
#   'student_id': 8539.0,
#   'scores': [{'type': 'exam', 'score': 60.76102311273852},
#    {'type': 'quiz', 'score': 53.57493754931665},
#    {'type': 'homework', 'score': 61.16109897565949},
#    {'type': 'homework', 'score': 79.70576218961355}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da268a'),
#   'student_id': 8543.0,
#   'scores': [{'type': 'exam', 'score': 10.572381587992762},
#    {'type': 'quiz', 'score': 13.42550868845034},
#    {'type': 'homework', 'score': 64.83808343713233},
#    {'type': 'homework', 'score': 52.41654944306195}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da2acc'),
#   'student_id': 8652.0,
#   'scores': [{'type': 'exam', 'score': 16.678711722102292},
#    {'type': 'quiz', 'score': 19.27105969231071},
#    {'type': 'homework', 'score': 61.37951898142383},
#    {'type': 'homework', 'score': 1.5033577979952528}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da2b8a'),
#   'student_id': 8671.0,
#   'scores': [{'type': 'exam', 'score': 18.679286481797575},
#    {'type': 'quiz', 'score': 73.09188619953434},
#    {'type': 'homework', 'score': 36.494467898691305},
#    {'type': 'homework', 'score': 42.39069922434363}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da2c43'),
#   'student_id': 8690.0,
#   'scores': [{'type': 'exam', 'score': 65.507960996833},
#    {'type': 'quiz', 'score': 24.811840155191987},
#    {'type': 'homework', 'score': 53.95556563564766},
#    {'type': 'homework', 'score': 28.029373578438378}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da2e8b'),
#   'student_id': 8748.0,
#   'scores': [{'type': 'exam', 'score': 33.290304786495774},
#    {'type': 'quiz', 'score': 51.7520484572878},
#    {'type': 'homework', 'score': 20.015614259418523},
#    {'type': 'homework', 'score': 37.58015839059592}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da2fb9'),
#   'student_id': 8778.0,
#   'scores': [{'type': 'exam', 'score': 17.310320566413615},
#    {'type': 'quiz', 'score': 60.32710908215917},
#    {'type': 'homework', 'score': 10.602992936736843},
#    {'type': 'homework', 'score': 47.65713286393706}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da331f'),
#   'student_id': 8865.0,
#   'scores': [{'type': 'exam', 'score': 14.470317876039807},
#    {'type': 'quiz', 'score': 79.65407391865077},
#    {'type': 'homework', 'score': 77.59149347720707},
#    {'type': 'homework', 'score': 9.958973673668137}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da3fbb'),
#   'student_id': 9188.0,
#   'scores': [{'type': 'exam', 'score': 21.084920464063195},
#    {'type': 'quiz', 'score': 79.20191578349083},
#    {'type': 'homework', 'score': 58.44021825157583},
#    {'type': 'homework', 'score': 57.266523634778935}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da43b7'),
#   'student_id': 9290.0,
#   'scores': [{'type': 'exam', 'score': 35.67614527385543},
#    {'type': 'quiz', 'score': 19.93682337124174},
#    {'type': 'homework', 'score': 1.2337044039791745},
#    {'type': 'homework', 'score': 48.709372451171426}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da46c8'),
#   'student_id': 9369.0,
#   'scores': [{'type': 'exam', 'score': 51.3224379425139},
#    {'type': 'quiz', 'score': 48.676965534845564},
#    {'type': 'homework', 'score': 37.6588443189799},
#    {'type': 'homework', 'score': 8.604754538569182}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da4eae'),
#   'student_id': 9571.0,
#   'scores': [{'type': 'exam', 'score': 9.558743478420407},
#    {'type': 'quiz', 'score': 17.2212252720527},
#    {'type': 'homework', 'score': 2.808075066370719},
#    {'type': 'homework', 'score': 18.835082341547928}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da4fe5'),
#   'student_id': 9602.0,
#   'scores': [{'type': 'exam', 'score': 36.06877248486906},
#    {'type': 'quiz', 'score': 58.534942443998716},
#    {'type': 'homework', 'score': 42.90554130009472},
#    {'type': 'homework', 'score': 29.16166047987554}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da58d0'),
#   'student_id': 9830.0,
#   'scores': [{'type': 'exam', 'score': 42.62134827577116},
#    {'type': 'quiz', 'score': 16.025960980952036},
#    {'type': 'homework', 'score': 31.208487018921073},
#    {'type': 'homework', 'score': 23.069128750370893}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da5c0f'),
#   'student_id': 9913.0,
#   'scores': [{'type': 'exam', 'score': 74.99723409556644},
#    {'type': 'quiz', 'score': 31.29498628820846},
#    {'type': 'homework', 'score': 4.720641335964137},
#    {'type': 'homework', 'score': 78.94045297535732}],
#   'class_id': 500.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8db27'),
#   'student_id': 60.0,
#   'scores': [{'type': 'exam', 'score': 31.866047311495795},
#    {'type': 'quiz', 'score': 0.08532524079455373},
#    {'type': 'homework', 'score': 18.99164972988361},
#    {'type': 'homework', 'score': 54.7812201885604}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8de80'),
#   'student_id': 145.0,
#   'scores': [{'type': 'exam', 'score': 18.662048835413604},
#    {'type': 'quiz', 'score': 17.552806326150517},
#    {'type': 'homework', 'score': 57.13487377474146},
#    {'type': 'homework', 'score': 75.01397969767524}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8deca'),
#   'student_id': 153.0,
#   'scores': [{'type': 'exam', 'score': 40.042921485030035},
#    {'type': 'quiz', 'score': 79.53056361623395},
#    {'type': 'homework', 'score': 6.858701047503779},
#    {'type': 'homework', 'score': 56.708641145710516}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d8ecf9'),
#   'student_id': 516.0,
#   'scores': [{'type': 'exam', 'score': 31.30883870037825},
#    {'type': 'quiz', 'score': 65.49114748417558},
#    {'type': 'homework', 'score': 9.897209906252602},
#    {'type': 'homework', 'score': 13.804263923332648}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d8ed6a'),
#   'student_id': 527.0,
#   'scores': [{'type': 'exam', 'score': 53.331788661000616},
#    {'type': 'quiz', 'score': 38.80828221331013},
#    {'type': 'homework', 'score': 34.99671633068397},
#    {'type': 'homework', 'score': 29.732701947882934}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d8ef2b'),
#   'student_id': 572.0,
#   'scores': [{'type': 'exam', 'score': 54.56645941135204},
#    {'type': 'quiz', 'score': 18.16817978473928},
#    {'type': 'homework', 'score': 72.36089764001167},
#    {'type': 'homework', 'score': 22.680684608100442}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d8f048'),
#   'student_id': 601.0,
#   'scores': [{'type': 'exam', 'score': 44.065209504710126},
#    {'type': 'quiz', 'score': 29.726340452573517},
#    {'type': 'homework', 'score': 2.0671718289702934},
#    {'type': 'homework', 'score': 7.710803273438616}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d9081e'),
#   'student_id': 1211.0,
#   'scores': [{'type': 'exam', 'score': 10.81606932110849},
#    {'type': 'quiz', 'score': 0.761666504779257},
#    {'type': 'homework', 'score': 7.144738998668632},
#    {'type': 'homework', 'score': 74.67326902760468}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d90b9c'),
#   'student_id': 1300.0,
#   'scores': [{'type': 'exam', 'score': 23.095951451622774},
#    {'type': 'quiz', 'score': 56.35954221782815},
#    {'type': 'homework', 'score': 4.894673061118359},
#    {'type': 'homework', 'score': 44.930895047974296}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d90d4f'),
#   'student_id': 1344.0,
#   'scores': [{'type': 'exam', 'score': 62.48887558833528},
#    {'type': 'quiz', 'score': 31.158554352739298},
#    {'type': 'homework', 'score': 45.61397658758336},
#    {'type': 'homework', 'score': 16.869446079093255}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d910bd'),
#   'student_id': 1431.0,
#   'scores': [{'type': 'exam', 'score': 50.255415405014745},
#    {'type': 'quiz', 'score': 8.569565289852765},
#    {'type': 'homework', 'score': 71.20150792725714},
#    {'type': 'homework', 'score': 77.5769148586254}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d9162b'),
#   'student_id': 1570.0,
#   'scores': [{'type': 'exam', 'score': 12.67315975374067},
#    {'type': 'quiz', 'score': 54.2077128531419},
#    {'type': 'homework', 'score': 8.925377380351874},
#    {'type': 'homework', 'score': 41.11493355220846}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d9178c'),
#   'student_id': 1606.0,
#   'scores': [{'type': 'exam', 'score': 57.34528707773149},
#    {'type': 'quiz', 'score': 24.173045837495522},
#    {'type': 'homework', 'score': 13.83897879026106},
#    {'type': 'homework', 'score': 2.5333512555511306}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d9214d'),
#   'student_id': 1855.0,
#   'scores': [{'type': 'exam', 'score': 78.55854568569583},
#    {'type': 'quiz', 'score': 77.7657909140105},
#    {'type': 'homework', 'score': 43.30517050510338},
#    {'type': 'homework', 'score': 74.90871293673447}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d921e3'),
#   'student_id': 1870.0,
#   'scores': [{'type': 'exam', 'score': 28.11275074495274},
#    {'type': 'quiz', 'score': 74.61803238590343},
#    {'type': 'homework', 'score': 18.62734169092375},
#    {'type': 'homework', 'score': 52.0447686617261}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d92e04'),
#   'student_id': 2181.0,
#   'scores': [{'type': 'exam', 'score': 30.978541569632966},
#    {'type': 'quiz', 'score': 59.66418667766238},
#    {'type': 'homework', 'score': 11.234629874292235},
#    {'type': 'homework', 'score': 39.316268644880914}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d93409'),
#   'student_id': 2335.0,
#   'scores': [{'type': 'exam', 'score': 39.88462455161243},
#    {'type': 'quiz', 'score': 57.381372219943806},
#    {'type': 'homework', 'score': 67.47960262144649},
#    {'type': 'homework', 'score': 29.63075202525407}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d93429'),
#   'student_id': 2338.0,
#   'scores': [{'type': 'exam', 'score': 39.03461458288508},
#    {'type': 'quiz', 'score': 45.61433358908874},
#    {'type': 'homework', 'score': 13.609939663319558},
#    {'type': 'homework', 'score': 62.75037212403777}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d93ed3'),
#   'student_id': 2611.0,
#   'scores': [{'type': 'exam', 'score': 33.24143742110702},
#    {'type': 'quiz', 'score': 63.43507469805992},
#    {'type': 'homework', 'score': 77.84963251215079},
#    {'type': 'homework', 'score': 24.74466810830467}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d94361'),
#   'student_id': 2728.0,
#   'scores': [{'type': 'exam', 'score': 34.45768751600139},
#    {'type': 'quiz', 'score': 31.726193749881904},
#    {'type': 'homework', 'score': 35.549435404777654},
#    {'type': 'homework', 'score': 68.63598750773023}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d95404'),
#   'student_id': 3154.0,
#   'scores': [{'type': 'exam', 'score': 50.711150960480964},
#    {'type': 'quiz', 'score': 36.96075890267486},
#    {'type': 'homework', 'score': 72.3547288410295},
#    {'type': 'homework', 'score': 58.62075808533772}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d9555c'),
#   'student_id': 3188.0,
#   'scores': [{'type': 'exam', 'score': 16.43624580708165},
#    {'type': 'quiz', 'score': 48.81946635640346},
#    {'type': 'homework', 'score': 53.46106807356207},
#    {'type': 'homework', 'score': 18.977304779646108}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d9570c'),
#   'student_id': 3231.0,
#   'scores': [{'type': 'exam', 'score': 77.7340450782878},
#    {'type': 'quiz', 'score': 34.18342524317236},
#    {'type': 'homework', 'score': 20.10686592731362},
#    {'type': 'homework', 'score': 51.192569208123416}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d96bd5'),
#   'student_id': 3763.0,
#   'scores': [{'type': 'exam', 'score': 48.551012118519935},
#    {'type': 'quiz', 'score': 11.366308866629227},
#    {'type': 'homework', 'score': 11.935801529118672},
#    {'type': 'homework', 'score': 57.07742513964891}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d96de3'),
#   'student_id': 3816.0,
#   'scores': [{'type': 'exam', 'score': 60.85298869882435},
#    {'type': 'quiz', 'score': 35.54392986199293},
#    {'type': 'homework', 'score': 19.009944443889815},
#    {'type': 'homework', 'score': 51.18801776735621}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d9763f'),
#   'student_id': 4030.0,
#   'scores': [{'type': 'exam', 'score': 17.093495290955175},
#    {'type': 'quiz', 'score': 19.763041733436182},
#    {'type': 'homework', 'score': 66.73996264341415},
#    {'type': 'homework', 'score': 60.577180185978364}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d977bb'),
#   'student_id': 4068.0,
#   'scores': [{'type': 'exam', 'score': 13.421191518407849},
#    {'type': 'quiz', 'score': 58.65302270943754},
#    {'type': 'homework', 'score': 54.812640963580264},
#    {'type': 'homework', 'score': 79.24277379232957}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d97848'),
#   'student_id': 4082.0,
#   'scores': [{'type': 'exam', 'score': 67.94731988535749},
#    {'type': 'quiz', 'score': 50.879718275828665},
#    {'type': 'homework', 'score': 21.043600584039236},
#    {'type': 'homework', 'score': 1.8509320101183335}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d978a6'),
#   'student_id': 4092.0,
#   'scores': [{'type': 'exam', 'score': 6.130602669264496},
#    {'type': 'quiz', 'score': 57.754593491424764},
#    {'type': 'homework', 'score': 45.4377093632353},
#    {'type': 'homework', 'score': 2.225864390447485}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d97d95'),
#   'student_id': 4218.0,
#   'scores': [{'type': 'exam', 'score': 19.20018582156394},
#    {'type': 'quiz', 'score': 5.882660123211481},
#    {'type': 'homework', 'score': 57.52586439140216},
#    {'type': 'homework', 'score': 58.256857419732356}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d97fb8'),
#   'student_id': 4273.0,
#   'scores': [{'type': 'exam', 'score': 42.61043508199136},
#    {'type': 'quiz', 'score': 76.99470292629827},
#    {'type': 'homework', 'score': 33.148210452602946},
#    {'type': 'homework', 'score': 64.42399655771418}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d98620'),
#   'student_id': 4437.0,
#   'scores': [{'type': 'exam', 'score': 79.00624758262393},
#    {'type': 'quiz', 'score': 48.717771748065886},
#    {'type': 'homework', 'score': 77.86543522519644},
#    {'type': 'homework', 'score': 61.885769799666576}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d986e6'),
#   'student_id': 4456.0,
#   'scores': [{'type': 'exam', 'score': 8.42615950962734},
#    {'type': 'quiz', 'score': 50.671078663028446},
#    {'type': 'homework', 'score': 39.001422141999186},
#    {'type': 'homework', 'score': 6.625131012109153}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d98bf9'),
#   'student_id': 4586.0,
#   'scores': [{'type': 'exam', 'score': 71.41861191767093},
#    {'type': 'quiz', 'score': 75.94036818857597},
#    {'type': 'homework', 'score': 61.81403565953067},
#    {'type': 'homework', 'score': 15.806891055552985}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d99011'),
#   'student_id': 4691.0,
#   'scores': [{'type': 'exam', 'score': 29.550434423112037},
#    {'type': 'quiz', 'score': 47.101789395005724},
#    {'type': 'homework', 'score': 50.54334636870873},
#    {'type': 'homework', 'score': 5.330060699296224}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d990fa'),
#   'student_id': 4714.0,
#   'scores': [{'type': 'exam', 'score': 5.165926570063473},
#    {'type': 'quiz', 'score': 22.17587909019365},
#    {'type': 'homework', 'score': 17.918122439574613},
#    {'type': 'homework', 'score': 22.496494674054635}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d990fe'),
#   'student_id': 4715.0,
#   'scores': [{'type': 'exam', 'score': 33.113110360007965},
#    {'type': 'quiz', 'score': 55.568582182168655},
#    {'type': 'homework', 'score': 23.028287419550796},
#    {'type': 'homework', 'score': 74.2849774174684}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d99275'),
#   'student_id': 4752.0,
#   'scores': [{'type': 'exam', 'score': 2.283347387496737},
#    {'type': 'quiz', 'score': 68.77673054680628},
#    {'type': 'homework', 'score': 74.27979537611313},
#    {'type': 'homework', 'score': 17.80350534244374}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d992f4'),
#   'student_id': 4765.0,
#   'scores': [{'type': 'exam', 'score': 73.81419808278862},
#    {'type': 'quiz', 'score': 65.7674710455246},
#    {'type': 'homework', 'score': 25.7447497067528},
#    {'type': 'homework', 'score': 22.13005700707088}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d99e37'),
#   'student_id': 5053.0,
#   'scores': [{'type': 'exam', 'score': 24.458012736916945},
#    {'type': 'quiz', 'score': 12.834698151579149},
#    {'type': 'homework', 'score': 48.04005669013893},
#    {'type': 'homework', 'score': 9.129623722067937}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d99f11'),
#   'student_id': 5075.0,
#   'scores': [{'type': 'exam', 'score': 70.514071844037},
#    {'type': 'quiz', 'score': 46.38330587349541},
#    {'type': 'homework', 'score': 51.327304106699735},
#    {'type': 'homework', 'score': 12.559837440380296}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ee604eb380b0d9a8cf'),
#   'student_id': 5324.0,
#   'scores': [{'type': 'exam', 'score': 32.25729264672408},
#    {'type': 'quiz', 'score': 4.651525703916137},
#    {'type': 'homework', 'score': 70.14738800202855},
#    {'type': 'homework', 'score': 53.49461412162552}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9b355'),
#   'student_id': 5594.0,
#   'scores': [{'type': 'exam', 'score': 54.62719689917077},
#    {'type': 'quiz', 'score': 26.76187414620973},
#    {'type': 'homework', 'score': 37.7362986288042},
#    {'type': 'homework', 'score': 6.652865735425384}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9b7da'),
#   'student_id': 5710.0,
#   'scores': [{'type': 'exam', 'score': 30.203038493687085},
#    {'type': 'quiz', 'score': 19.604667830157496},
#    {'type': 'homework', 'score': 12.050355389604594},
#    {'type': 'homework', 'score': 71.20151057559711}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9c624'),
#   'student_id': 6075.0,
#   'scores': [{'type': 'exam', 'score': 31.953319072493258},
#    {'type': 'quiz', 'score': 79.47313384755874},
#    {'type': 'homework', 'score': 9.033398104175772},
#    {'type': 'homework', 'score': 2.272037155183715}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9c6b8'),
#   'student_id': 6090.0,
#   'scores': [{'type': 'exam', 'score': 35.4721788979275},
#    {'type': 'quiz', 'score': 59.343052127696694},
#    {'type': 'homework', 'score': 41.02504945183092},
#    {'type': 'homework', 'score': 42.544034839002144}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9c6c6'),
#   'student_id': 6092.0,
#   'scores': [{'type': 'exam', 'score': 46.30583320296153},
#    {'type': 'quiz', 'score': 7.381272452067611},
#    {'type': 'homework', 'score': 27.5707081620446},
#    {'type': 'homework', 'score': 30.622241460443433}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9c796'),
#   'student_id': 6112.0,
#   'scores': [{'type': 'exam', 'score': 37.15794428698294},
#    {'type': 'quiz', 'score': 24.495277601290034},
#    {'type': 'homework', 'score': 59.43810459635964},
#    {'type': 'homework', 'score': 21.495990078587024}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9cf61'),
#   'student_id': 6312.0,
#   'scores': [{'type': 'exam', 'score': 11.863878615203237},
#    {'type': 'quiz', 'score': 42.79963264939849},
#    {'type': 'homework', 'score': 69.11775397361455},
#    {'type': 'homework', 'score': 31.684494627888647}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9cf83'),
#   'student_id': 6315.0,
#   'scores': [{'type': 'exam', 'score': 5.218654266135891},
#    {'type': 'quiz', 'score': 26.437739451763985},
#    {'type': 'homework', 'score': 44.46667016633893},
#    {'type': 'homework', 'score': 48.09203086629596}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9d210'),
#   'student_id': 6381.0,
#   'scores': [{'type': 'exam', 'score': 0.428131661215958},
#    {'type': 'quiz', 'score': 52.64768462999799},
#    {'type': 'homework', 'score': 41.89143498936768},
#    {'type': 'homework', 'score': 45.60124130932181}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9d44a'),
#   'student_id': 6438.0,
#   'scores': [{'type': 'exam', 'score': 61.78741121321004},
#    {'type': 'quiz', 'score': 68.75515661960908},
#    {'type': 'homework', 'score': 16.262226439855333},
#    {'type': 'homework', 'score': 36.09924128770541}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9d82f'),
#   'student_id': 6537.0,
#   'scores': [{'type': 'exam', 'score': 20.691348934217423},
#    {'type': 'quiz', 'score': 46.9243216249544},
#    {'type': 'homework', 'score': 10.88337874107519},
#    {'type': 'homework', 'score': 65.47701024582636}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9e141'),
#   'student_id': 6769.0,
#   'scores': [{'type': 'exam', 'score': 76.93062045273994},
#    {'type': 'quiz', 'score': 43.699747278256396},
#    {'type': 'homework', 'score': 25.86045595294196},
#    {'type': 'homework', 'score': 67.5822374651598}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7ef604eb380b0d9e4a4'),
#   'student_id': 6856.0,
#   'scores': [{'type': 'exam', 'score': 15.14228216604787},
#    {'type': 'quiz', 'score': 62.49358047736101},
#    {'type': 'homework', 'score': 71.91582225109029},
#    {'type': 'homework', 'score': 74.81155448862287}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0d9eecb'),
#   'student_id': 7116.0,
#   'scores': [{'type': 'exam', 'score': 29.807739010354585},
#    {'type': 'quiz', 'score': 47.11108700142383},
#    {'type': 'homework', 'score': 36.238615494552164},
#    {'type': 'homework', 'score': 46.249393668127325}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0d9f0ad'),
#   'student_id': 7164.0,
#   'scores': [{'type': 'exam', 'score': 42.27367858300926},
#    {'type': 'quiz', 'score': 3.5979163399486036},
#    {'type': 'homework', 'score': 19.17915787466121},
#    {'type': 'homework', 'score': 17.015102639904413}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0d9f431'),
#   'student_id': 7254.0,
#   'scores': [{'type': 'exam', 'score': 52.425075053480526},
#    {'type': 'quiz', 'score': 29.61225735112244},
#    {'type': 'homework', 'score': 79.80452898330998},
#    {'type': 'homework', 'score': 48.500639176540716}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0d9f4fd'),
#   'student_id': 7275.0,
#   'scores': [{'type': 'exam', 'score': 32.32940937655242},
#    {'type': 'quiz', 'score': 28.148541026631502},
#    {'type': 'homework', 'score': 58.26629001525085},
#    {'type': 'homework', 'score': 31.961269439498473}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0d9f71e'),
#   'student_id': 7329.0,
#   'scores': [{'type': 'exam', 'score': 65.74598471407582},
#    {'type': 'quiz', 'score': 9.567850945924661},
#    {'type': 'homework', 'score': 29.225056269925354},
#    {'type': 'homework', 'score': 46.26314895620728}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da009c'),
#   'student_id': 7572.0,
#   'scores': [{'type': 'exam', 'score': 44.40603562675724},
#    {'type': 'quiz', 'score': 23.305804072356008},
#    {'type': 'homework', 'score': 11.525997506507613},
#    {'type': 'homework', 'score': 71.73263150417691}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da04a0'),
#   'student_id': 7675.0,
#   'scores': [{'type': 'exam', 'score': 33.851914118888516},
#    {'type': 'quiz', 'score': 22.52928953221456},
#    {'type': 'homework', 'score': 29.463706121349208},
#    {'type': 'homework', 'score': 75.2291628777573}],
#   'class_id': 499.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da0594'),
#   'student_id': 7699.0,
# ...
#   'scores': [{'type': 'exam', 'score': 49.44195898908974},
#    {'type': 'quiz', 'score': 27.540002828936807},
#    {'type': 'homework', 'score': 78.29642197712636},
#    {'type': 'homework', 'score': 63.71636112833545}],
#   'class_id': 489.0},
#  {'_id': ObjectId('56d5f7f0604eb380b0da23e4'),
#   'student_id': 8475.0,
#   'scores': [{'type': 'exam', 'score': 68.76656612760901},
#    {'type': 'quiz', 'score': 36.30853607948071},
#    {'type': 'homework', 'score': 76.21342179819013},
#    {'type': 'homework', 'score': 54.53194358568319}],
#   'class_id': 489.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da2658'),
#   'student_id': 8538.0,
#   'scores': [{'type': 'exam', 'score': 67.75899443654033},
#    {'type': 'quiz', 'score': 28.03289048594526},
#    {'type': 'homework', 'score': 28.969242258083415},
#    {'type': 'homework', 'score': 4.916166714638759}],
#   'class_id': 489.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da2e29'),
#   'student_id': 8738.0,
#   'scores': [{'type': 'exam', 'score': 9.741475748208995},
#    {'type': 'quiz', 'score': 1.3265927772717068},
#    {'type': 'homework', 'score': 28.01336172417559},
#    {'type': 'homework', 'score': 38.04936850375379}],
#   'class_id': 489.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da395e'),
#   'student_id': 9025.0,
#   'scores': [{'type': 'exam', 'score': 76.83117504081102},
#    {'type': 'quiz', 'score': 11.996960852793691},
#    {'type': 'homework', 'score': 62.473967120245696},
#    {'type': 'homework', 'score': 76.60880238767918}],
#   'class_id': 489.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da3bfc'),
#   'student_id': 9092.0,
#   'scores': [{'type': 'exam', 'score': 73.11955469322454},
#    {'type': 'quiz', 'score': 52.42057956809536},
#    {'type': 'homework', 'score': 24.054804812902596},
#    {'type': 'homework', 'score': 64.30642797631059}],
#   'class_id': 489.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da4855'),
#   'student_id': 9408.0,
#   'scores': [{'type': 'exam', 'score': 52.6097409851739},
#    {'type': 'quiz', 'score': 31.510273935857512},
#    {'type': 'homework', 'score': 71.2521111232472},
#    {'type': 'homework', 'score': 43.88392183303162}],
#   'class_id': 489.0},
#  {'_id': ObjectId('56d5f7f1604eb380b0da4d75'),
#   'student_id': 9539.0,
#   'scores': [{'type': 'exam', 'score': 8.6318027682465},
#    {'type': 'quiz', 'score': 69.41382612676517},
#    {'type': 'homework', 'score': 21.37345453309223},
#    {'type': 'homework', 'score': 32.055117096517215}],
#   'class_id': 489.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8dd30'),
#   'student_id': 112.0,
#   'scores': [{'type': 'exam', 'score': 22.790796723753047},
#    {'type': 'quiz', 'score': 54.71820448520886},
#    {'type': 'homework', 'score': 2.8147852974770293},
#    {'type': 'homework', 'score': 66.20725470842284}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8e01a'),
#   'student_id': 186.0,
#   'scores': [{'type': 'exam', 'score': 74.79679984437543},
#    {'type': 'quiz', 'score': 6.496551381567484},
#    {'type': 'homework', 'score': 24.965764104333154},
#    {'type': 'homework', 'score': 1.2468140418912421}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8e09b'),
#   'student_id': 199.0,
#   'scores': [{'type': 'exam', 'score': 28.640439241609307},
#    {'type': 'quiz', 'score': 73.04572405498597},
#    {'type': 'homework', 'score': 54.16216304223107},
#    {'type': 'homework', 'score': 13.813521923344974}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8e2ca'),
#   'student_id': 255.0,
#   'scores': [{'type': 'exam', 'score': 45.94935781011644},
#    {'type': 'quiz', 'score': 52.28384721753711},
#    {'type': 'homework', 'score': 32.50024251692215},
#    {'type': 'homework', 'score': 32.76886932004215}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8e41b'),
#   'student_id': 289.0,
#   'scores': [{'type': 'exam', 'score': 43.32066796495351},
#    {'type': 'quiz', 'score': 20.543430535412988},
#    {'type': 'homework', 'score': 25.399187411061995},
#    {'type': 'homework', 'score': 8.818380276076898}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7eb604eb380b0d8e909'),
#   'student_id': 415.0,
#   'scores': [{'type': 'exam', 'score': 39.205205107195454},
#    {'type': 'quiz', 'score': 75.87075185609508},
#    {'type': 'homework', 'score': 10.182193079540447},
#    {'type': 'homework', 'score': 7.268943625847557}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d8ed3c'),
#   'student_id': 523.0,
#   'scores': [{'type': 'exam', 'score': 45.01805558317822},
#    {'type': 'quiz', 'score': 11.014010868180756},
#    {'type': 'homework', 'score': 3.7131745324807564},
#    {'type': 'homework', 'score': 12.461608324440688}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d8f4ef'),
#   'student_id': 720.0,
#   'scores': [{'type': 'exam', 'score': 0.6033648038269224},
#    {'type': 'quiz', 'score': 16.521493758664707},
#    {'type': 'homework', 'score': 51.165557033996144},
#    {'type': 'homework', 'score': 1.7993208622366308}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d8f83c'),
#   'student_id': 804.0,
#   'scores': [{'type': 'exam', 'score': 78.84739549118767},
#    {'type': 'quiz', 'score': 50.40354471632173},
#    {'type': 'homework', 'score': 57.3714144657781},
#    {'type': 'homework', 'score': 73.35904288859417}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d9018e'),
#   'student_id': 1043.0,
#   'scores': [{'type': 'exam', 'score': 75.78278652396891},
#    {'type': 'quiz', 'score': 59.059584513528186},
#    {'type': 'homework', 'score': 39.0353480646494},
#    {'type': 'homework', 'score': 60.71931228052563}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d9027e'),
#   'student_id': 1067.0,
#   'scores': [{'type': 'exam', 'score': 32.85383798960647},
#    {'type': 'quiz', 'score': 16.13163329333911},
#    {'type': 'homework', 'score': 40.53208703850022},
#    {'type': 'homework', 'score': 61.86944884670661}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d90516'),
#   'student_id': 1133.0,
#   'scores': [{'type': 'exam', 'score': 31.36186879019025},
#    {'type': 'quiz', 'score': 52.68556098303032},
#    {'type': 'homework', 'score': 50.4188708824187},
#    {'type': 'homework', 'score': 16.199410904567134}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d9055b'),
#   'student_id': 1140.0,
#   'scores': [{'type': 'exam', 'score': 42.48185281013059},
#    {'type': 'quiz', 'score': 78.82535166113217},
#    {'type': 'homework', 'score': 29.223439455774248},
#    {'type': 'homework', 'score': 59.850629433251136}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d90a67'),
#   'student_id': 1269.0,
#   'scores': [{'type': 'exam', 'score': 58.98078667688329},
#    {'type': 'quiz', 'score': 73.703931037625},
#    {'type': 'homework', 'score': 25.541206960283468},
#    {'type': 'homework', 'score': 70.00151462345924}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d913f1'),
#   'student_id': 1513.0,
#   'scores': [{'type': 'exam', 'score': 36.00424193703542},
#    {'type': 'quiz', 'score': 30.678225824176508},
#    {'type': 'homework', 'score': 22.266108313938236},
#    {'type': 'homework', 'score': 30.131106614290783}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d91411'),
#   'student_id': 1517.0,
#   'scores': [{'type': 'exam', 'score': 12.635490766497615},
#    {'type': 'quiz', 'score': 62.311901797278054},
#    {'type': 'homework', 'score': 55.87234091506412},
#    {'type': 'homework', 'score': 64.76932337443067}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d914f8'),
#   'student_id': 1540.0,
#   'scores': [{'type': 'exam', 'score': 6.394116732780242},
#    {'type': 'quiz', 'score': 49.22311441045417},
#    {'type': 'homework', 'score': 35.85000018439351},
#    {'type': 'homework', 'score': 41.74320473783262}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d91cc6'),
#   'student_id': 1740.0,
#   'scores': [{'type': 'exam', 'score': 12.50728123208711},
#    {'type': 'quiz', 'score': 41.48652464729585},
#    {'type': 'homework', 'score': 27.68741351702061},
#    {'type': 'homework', 'score': 78.68155063866537}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d91d0e'),
#   'student_id': 1747.0,
#   'scores': [{'type': 'exam', 'score': 36.983891227179534},
#    {'type': 'quiz', 'score': 53.37888375894655},
#    {'type': 'homework', 'score': 49.97285754864668},
#    {'type': 'homework', 'score': 77.99071471455103}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d9211b'),
#   'student_id': 1850.0,
#   'scores': [{'type': 'exam', 'score': 9.93354004956981},
#    {'type': 'quiz', 'score': 35.175358846433355},
#    {'type': 'homework', 'score': 12.80406744240359},
#    {'type': 'homework', 'score': 30.680330207714736}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d92450'),
#   'student_id': 1933.0,
#   'scores': [{'type': 'exam', 'score': 26.293612076293016},
#    {'type': 'quiz', 'score': 1.7104450348881306},
#    {'type': 'homework', 'score': 79.61683256814158},
#    {'type': 'homework', 'score': 57.54269555962425}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d925be'),
#   'student_id': 1969.0,
#   'scores': [{'type': 'exam', 'score': 65.52161213343936},
#    {'type': 'quiz', 'score': 69.00146016188037},
#    {'type': 'homework', 'score': 52.38345000363167},
#    {'type': 'homework', 'score': 18.932295333719008}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ec604eb380b0d926e6'),
#   'student_id': 1999.0,
#   'scores': [{'type': 'exam', 'score': 40.70169044807614},
#    {'type': 'quiz', 'score': 52.84409169368487},
#    {'type': 'homework', 'score': 26.063065529661},
#    {'type': 'homework', 'score': 22.962020606502133}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d927ca'),
#   'student_id': 2022.0,
#   'scores': [{'type': 'exam', 'score': 73.45862872714872},
#    {'type': 'quiz', 'score': 19.332215259413477},
#    {'type': 'homework', 'score': 72.35612748825662},
#    {'type': 'homework', 'score': 56.90833303130985}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d92ec0'),
#   'student_id': 2200.0,
#   'scores': [{'type': 'exam', 'score': 14.766202039353338},
#    {'type': 'quiz', 'score': 59.04174105703189},
#    {'type': 'homework', 'score': 69.81918795148923},
#    {'type': 'homework', 'score': 25.30645498654247}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d9378c'),
#   'student_id': 2425.0,
#   'scores': [{'type': 'exam', 'score': 75.54557782745339},
#    {'type': 'quiz', 'score': 29.841149146974267},
#    {'type': 'homework', 'score': 61.7520450349218},
#    {'type': 'homework', 'score': 38.64446121514737}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d93eaf'),
#   'student_id': 2608.0,
#   'scores': [{'type': 'exam', 'score': 77.77626465076087},
#    {'type': 'quiz', 'score': 21.95952755407028},
#    {'type': 'homework', 'score': 44.48109772263768},
#    {'type': 'homework', 'score': 32.56300525227888}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d93f38'),
#   'student_id': 2621.0,
#   'scores': [{'type': 'exam', 'score': 62.83534065864733},
#    {'type': 'quiz', 'score': 29.850368918248037},
#    {'type': 'homework', 'score': 17.58204524235478},
#    {'type': 'homework', 'score': 72.32032088846111}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d941f6'),
#   'student_id': 2692.0,
#   'scores': [{'type': 'exam', 'score': 60.63283210093573},
#    {'type': 'quiz', 'score': 74.67730102778118},
#    {'type': 'homework', 'score': 4.047834843509735},
#    {'type': 'homework', 'score': 72.15955077081576}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d94217'),
#   'student_id': 2695.0,
#   'scores': [{'type': 'exam', 'score': 21.506677196278932},
#    {'type': 'quiz', 'score': 26.946588380506686},
#    {'type': 'homework', 'score': 15.464452346202728},
#    {'type': 'homework', 'score': 72.30527658346875}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d94463'),
#   'student_id': 2754.0,
#   'scores': [{'type': 'exam', 'score': 4.549453508146306},
#    {'type': 'quiz', 'score': 16.715057855866178},
#    {'type': 'homework', 'score': 34.357779847472884},
#    {'type': 'homework', 'score': 44.07301986242027}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d94777'),
#   'student_id': 2832.0,
#   'scores': [{'type': 'exam', 'score': 8.095184585061011},
#    {'type': 'quiz', 'score': 38.07461422085628},
#    {'type': 'homework', 'score': 69.88907350091415},
#    {'type': 'homework', 'score': 6.096908335705031}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d94ced'),
#   'student_id': 2972.0,
#   'scores': [{'type': 'exam', 'score': 4.850624269512971},
#    {'type': 'quiz', 'score': 27.900382100795728},
#    {'type': 'homework', 'score': 9.799675423560917},
#    {'type': 'homework', 'score': 40.749207688001256}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d94d19'),
#   'student_id': 2977.0,
#   'scores': [{'type': 'exam', 'score': 44.32326918296783},
#    {'type': 'quiz', 'score': 35.53658447345938},
#    {'type': 'homework', 'score': 31.017972595370857},
#    {'type': 'homework', 'score': 41.49865324639972}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d94ff5'),
#   'student_id': 3050.0,
#   'scores': [{'type': 'exam', 'score': 10.561904100791919},
#    {'type': 'quiz', 'score': 70.67815643703894},
#    {'type': 'homework', 'score': 44.9182936035765},
#    {'type': 'homework', 'score': 71.40725252427414}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d9513f'),
#   'student_id': 3083.0,
#   'scores': [{'type': 'exam', 'score': 64.00740714451695},
#    {'type': 'quiz', 'score': 24.21435746983893},
#    {'type': 'homework', 'score': 34.34314908199212},
#    {'type': 'homework', 'score': 31.0541831821876}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d956c6'),
#   'student_id': 3224.0,
#   'scores': [{'type': 'exam', 'score': 56.52137887353038},
#    {'type': 'quiz', 'score': 31.731416266745306},
#    {'type': 'homework', 'score': 9.246793366620565},
#    {'type': 'homework', 'score': 66.34821543239141}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d95719'),
#   'student_id': 3233.0,
#   'scores': [{'type': 'exam', 'score': 33.26204986495994},
#    {'type': 'quiz', 'score': 47.59149659684853},
#    {'type': 'homework', 'score': 64.86941168612607},
#    {'type': 'homework', 'score': 76.83236763844677}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d95a82'),
#   'student_id': 3320.0,
#   'scores': [{'type': 'exam', 'score': 37.44968017308861},
#    {'type': 'quiz', 'score': 9.685648226407151},
#    {'type': 'homework', 'score': 0.4064543086003902},
#    {'type': 'homework', 'score': 39.093622722702406}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d95adb'),
#   'student_id': 3329.0,
#   'scores': [{'type': 'exam', 'score': 3.493180091851389},
#    {'type': 'quiz', 'score': 43.32693711986766},
#    {'type': 'homework', 'score': 41.663616313037565},
#    {'type': 'homework', 'score': 2.1074474777904806}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d95af1'),
#   'student_id': 3331.0,
#   'scores': [{'type': 'exam', 'score': 46.78983104615907},
#    {'type': 'quiz', 'score': 74.71719865543683},
#    {'type': 'homework', 'score': 62.357810638888324},
#    {'type': 'homework', 'score': 15.908210372263444}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d95c5c'),
#   'student_id': 3367.0,
#   'scores': [{'type': 'exam', 'score': 13.903311438923993},
#    {'type': 'quiz', 'score': 68.35244107011799},
#    {'type': 'homework', 'score': 22.265439978759048},
#    {'type': 'homework', 'score': 72.62105555514083}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d9617a'),
#   'student_id': 3498.0,
#   'scores': [{'type': 'exam', 'score': 77.34884375605476},
#    {'type': 'quiz', 'score': 0.12563353443371117},
#    {'type': 'homework', 'score': 71.8368283708813},
#    {'type': 'homework', 'score': 13.71349457424732}],
#   'class_id': 488.0},
#  {'_id': ObjectId('56d5f7ed604eb380b0d967a0'),
#   'student_id': 3656.0,
#   'scores': [{'type': 'exam', 'score': 14.148595164700218},
#    {'type': 'quiz', 'score': 72.2696155181433},
#    {'type': 'homework', 'score': 58.324340659770826},
#    {'type': 'homework', 'score': 26.03871065272585}],
#   'class_id': 488.0},
#  ...]

# %% [markdown]
# ## Problem 5
#
# Return the count of all the documents where:
# ~~~
# 1) "genres" not in the following: "Drama","Fantasy"
# ~~~
#
# Write 2 different queries to return this count.

# %% [markdown]
# **expected output**
#
#
# ```
# output1 = value
# output2 = value
#
# ```

# %%
# 1. 
movies.count_documents({"genres":{'$nin':["Drama","Fantasy"]}})
# Out:
# 8993

# %%
#2. 
movies.count_documents({"genres": { '$not': { '$in':["Drama","Fantasy"] } } })
# Out:
# 8993

# %% [markdown]
# ## Problem 6
#
# Return the documents from the airbnb collection where:
# ~~~
# 1) "amenities" field has values in: "TV", "Wifi"
# 2) "reviews" exists and is not equal to []
# 3) "property_type" is in one of the following values: "Hostel","Hotel" OR "room_type" is in one of the following values "Entire home/apt","Private room"
# 4) The field in the array of embedded objects "reviews.reviewer_name" is not equal to "Theo" OR the "reviews.reviewer_name" field is not equal to "Marie"
# 5) Only return the following "_id", "amenities", "reviews.reviewer_name","room_type","property_type", "name", "accommodates"
# 6) Sort by name descending, accommodates descending
# 7) Limit to 1 result
# ~~~

# %% [markdown]
# **expected output**
#
# ```
# [{'_id': '',
#   'accommodates': #,
#   'amenities': ['TV','value2','value3'],
#   'name': 'name1',
#   'property_type': 'property1',
#   'reviews': [{'reviewer_name': 'name1'}],
#   'room_type': 'room_value'}]
# ```

# %%
list(airbnb.find({"amenities":{"$in":['TV','Wifi']},"reviews":{'$ne':[],"$exists":True},
            "$or":[{"property_type":{"$in":['Hostel',"Hotel"]}},
                   {"room_type":{"$in":["Entire home/apt","Private room"]}}],
            "$nor":[{"reviews.reviewer_name":{"$eq":"Theo"}},
                   {"reviews.reviewer_name":{"$eq":'Marie'}}]
                  
           
           }
           ,{'_id':1,"amenities":1,"reviews.reviewer_name":1,"room_type":1,"property_type":1, "name":1,"accommodates":1})
     .sort([('name',-1),('accommodates',-1)])
     .limit(1))
# Out:
# [{'_id': '32369195',
#   'name': '默默|sushe素舍  万象城/罗湖口岸/三地铁口/粤港美食/商旅首选一室一厅公寓',
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'amenities': ['TV',
#    'Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Pets allowed',
#    'Elevator',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Smart lock'],
#   'reviews': [{'reviewer_name': 'Chun Ki'}]}]

# %% [markdown]
# ## Problem 7
#
# In the movies collection:
#
# ~~~
# 1) "genres" not equal to Documentary
# 2) "imdb.rating" greater than 8
# 3) "tomatoes.viewer.rating" greater than 4
# 4) "rated" in one of the following values:"APPROVED","PG-13","PG" OR the "year" is in one of the following values:2000, 2008, 2010, 2012 OR "runtime" greater than 100
# 5) Only return "_id","genres", "imdb.rating", "tomatoes.viewer.rating", "rated","year","runtime"
# 6) Limit to 1 result
# 7) Sort by "runtime" ascending and "year" descending
# ~~~

# %% [markdown]
# **expected output**
#
# ```
# [{'_id': ObjectId(''),
#   'genres': ['genre1', 'genre2',..],
#   'imdb': {'rating': 9.4},
#   'rated': 'rated1',
#   'runtime': runtime1,
#   'tomatoes': {'viewer': {'rating': 5.3}},
#   'year': year1}]
# ```

# %%
list(movies.find({"genres":{"$ne":'Documentary'},
                  "imdb.rating":{'$gt':8},"tomatoes.viewer.rating":{'$gt':4},
            "$or":[{"rated":{"$in":["APPROVED","PG-13","PG"]}},
                   {"year":{"$in":[2000,2008,2010,2012]}},
                  {"runtime":{"$gt":100}}]
           
           }
           ,{'_id':1,"genres":1,"imdb.rating":1,"tomatoes.viewer.rating":1,"rated":1, "year":1,"runtime":1})
     .sort([("runtime",1),("year",-1)])
     .limit(1))
# Out:
# [{'_id': ObjectId('573a13a3f29313caabd0f030'),
#   'genres': ['Animation', 'Short', 'Comedy'],
#   'runtime': 3,
#   'rated': 'G',
#   'year': 2000,
#   'imdb': {'rating': 8.2},
#   'tomatoes': {'viewer': {'rating': 4.1}}}]

# %% [markdown]
# ## Problem 8
#
# Return the document from the companies collection where the following are true:
# ~~~
# 1) "number_of_employees" is greater than 10
# 2) One object in the "funding_rounds" array has a "funded_day" field value of 1, a "funded_month" between 9 and 12, and a "raised_amount" of greater than or equal to 1000000
# 3) One object in the "investments" array which is embedded in the "funding_rounds" array has a "financial_org.name" field value of "Sequoia Capital" and "financial_org.permalink" field value of "sequoia-capital"
# 4) Return the "number_of_employees", "name", and "funding_rounds"
# 5) Limit to 1 result
# 6) Sort by name ascending and number_of_employees descending
# ~~~

# %% [markdown]
# **expected output**
#
# ```
# [{'_id': ObjectId(''),
#   'funding_rounds': [{'funded_day': 1,
#     'funded_month': 12,
#     'funded_year': #,
#     'id': #,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'Sequoia Capital',
#        'permalink': 'sequoia-capital'},
#       'person': {'first_name': 'name1',
#        'last_name': 'last1',
#        'permalink': 'first-last'}},...],
#     'raised_amount': 1000000
#      .....}],
#      'name': 'name1',
#      'number_of_employees': #
# ```

# %%
list(companies.find({"number_of_employees":{'$gt':10},
                     "$and":[{"funding_rounds.funded_day":{"$eq":1}},
                             {"funding_rounds.funded_month":{"$gte":9,"$lte":12}},
                             {"funding_rounds.raised_amount":{"$gte":1000000}}],
                    "$and":[ {"funding_rounds.investments.financial_org.name":"Sequoia Capital"},
                            {"funding_rounds.investments.financial_org.permalink":"sequoia-capital"}]
           
           }
           ,{'_id':0,"number_of_employees":1,"name":1,"funding_rounds":1})
     .sort([("name",1),("number_of_employees",-1)])
     .limit(1))
# Out:
# [{'name': 'Aster Data Systems',
#   'number_of_employees': 50,
#   'funding_rounds': [{'id': 2324,
#     'round_code': 'angel',
#     'source_url': '',
#     'source_description': '',
#     'raised_amount': 1000000,
#     'raised_currency_code': 'USD',
#     'funded_year': 2005,
#     'funded_month': 11,
#     'funded_day': 1,
#     'investments': [{'company': None,
#       'financial_org': None,
#       'person': {'first_name': 'David',
#        'last_name': 'Cheriton',
#        'permalink': 'david-cheriton'}},
#      {'company': None,
#       'financial_org': None,
#       'person': {'first_name': 'Anand',
#        'last_name': 'Rajaraman',
#        'permalink': 'anand-rajaraman'}},
#      {'company': None,
#       'financial_org': None,
#       'person': {'first_name': 'Ron',
#        'last_name': 'Conway',
#        'permalink': 'ron-conway'}},
#      {'company': None,
#       'financial_org': {'name': 'First Round Capital',
#        'permalink': 'first-round-capital'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'SV Angel', 'permalink': 'sv-angel'},
#       'person': None}]},
#    {'id': 2325,
#     'round_code': 'a',
#     'source_url': '',
#     'source_description': '',
#     'raised_amount': 5000000,
#     'raised_currency_code': 'USD',
#     'funded_year': 2007,
#     'funded_month': 5,
#     'funded_day': 1,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'Sequoia Capital',
#        'permalink': 'sequoia-capital'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'Cambrian Ventures',
#        'permalink': 'cambrian-ventures'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'First Round Capital',
#        'permalink': 'first-round-capital'},
#       'person': None}]},
#    {'id': 4568,
#     'round_code': 'b',
#     'source_url': 'http://www.asterdata.com/news/090225_aster_IVP_funding.php',
#     'source_description': 'Aster Data Systems Extends oversubscribed Series B Funding to $17 Million',
#     'raised_amount': 17000000,
#     'raised_currency_code': 'USD',
#     'funded_year': 2009,
#     'funded_month': 2,
#     'funded_day': 25,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'Jafco Ventures',
#        'permalink': 'jafco-ventures'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'Sequoia Capital',
#        'permalink': 'sequoia-capital'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'Cambrian Ventures',
#        'permalink': 'cambrian-ventures'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'First Round Capital',
#        'permalink': 'first-round-capital'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'Institutional Venture Partners',
#        'permalink': 'institutional-venture-partners'},
#       'person': None}]},
#    {'id': 18492,
#     'round_code': 'c',
#     'source_url': 'http://www.finsmes.com/2010/09/aster-data-closes-30m-series-c.html',
#     'source_description': 'Aster Data Closes $30M Series C Financing Round',
#     'raised_amount': 30000000,
#     'raised_currency_code': 'USD',
#     'funded_year': 2010,
#     'funded_month': 9,
#     'funded_day': 22,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'Sequoia Capital',
#        'permalink': 'sequoia-capital'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'Jafco Ventures',
#        'permalink': 'jafco-ventures'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'Institutional Venture Partners',
#        'permalink': 'institutional-venture-partners'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'Cambrian Ventures',
#        'permalink': 'cambrian-ventures'},
#       'person': None},
#      {'company': None,
#       'financial_org': None,
#       'person': {'first_name': 'David',
#        'last_name': 'Cheriton',
#        'permalink': 'david-cheriton'}}]}]}]

# %% [markdown]
# ## Problem 9
#
# Write and execute the following as a MongoDB query.
# ~~~
# SELECT tomatoes.viewer.rating, awards.wins, imdb.rating, _id, title
# FROM movies
# WHERE awards.wins > 3
# OR (imdb.rating BETWEEN 7.5 AND 9 AND tomatoes.viewer.rating > 3.5)
# ORDER BY title
# LIMIT 1
# ~~~

# %% [markdown]
# **expected output**
#
# ```
# [{'_id': ObjectId(''),
#   'awards': {'wins': #},
#   'imdb': {'rating': #},
#   'title': "title1",
#   'tomatoes': {'viewer': {'rating': #}}}]
# ```

# %%
list(movies.find({
            "$or":[{"awards.wins":{"$gt":3}},
                   {"imdb.rating":{"$gte":7.5,"$lte":9},"tomatoes.viewer.rating":{"$gt":3.5}}
           
                  ]}
           ,{'_id':1,"tomatoes.viewer.rating":1,"awards.wins":1,"imdb.rating":1,"title":1})
     .sort('title',1)
     .limit(1))
# Out:
# [{'_id': ObjectId('573a13dff29313caabdb9439'),
#   'imdb': {'rating': 7.2},
#   'title': "'71",
#   'tomatoes': {'viewer': {'rating': 3.9}},
#   'awards': {'wins': 8}}]

# %% [markdown]
# ## Problem 10
#
# Write and execute the following as a MongoDB query.
#
# ~~~
# SELECT _id, genres, runtime, type
# FROM movies
# WHERE (genres="Short" OR type="series") AND runtime < 30
# ORDER BY runtime DESC
# LIMIT 1
# ~~~

# %% [markdown]
# **expected output**
#
# ```
# [{'_id': ObjectId(''),
#   'genres': ['genre1', 'genre2'],
#   'runtime': 20,
#   'type': 'x'}]
# ```

# %%
list(movies.find({"$and":[{'$or':[{'genres':{'$eq':'Short'}},{'type':{'$eq':'series'}}]},{'runtime':{'$lt':30}}]}
           ,{'_id':1,"genres":1,"runtime":1,"type":1})
     .sort('runtime',-1)
    .limit(1) )
# Out:
# [{'_id': ObjectId('573a1392f29313caabcd9bf8'),
#   'genres': ['Comedy', 'Short'],
#   'runtime': 29,
#   'type': 'movie'}]
